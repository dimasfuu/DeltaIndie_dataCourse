# %% [markdown]
# # 1. Perkenalan

# %% [markdown]
# **Nama : Dimas Furqon P.**
# **Kelas : Data Science Delta Indie Course**

# %% [markdown]
# # 2. Latar Belakang

# %% [markdown]
# ## 2.a Data Overview

# %% [markdown]
# Obesity Prediction Dataset adalah sebuah dataset yang digunakan untuk mengestimasi level obesitas berdasarkan beberapa variabel penyebab, diantaranya :
# 1. Kebiasaan/pola makan
# 2. Riwayat keluarga dan kondisi kesehatan.
#
# Data tersebut diambil dari sekelompok individu yang berasal dari beberapa negara seperti, Meksiko, Peru dan Kolombia, yang mencakup 16 gaya hidup yang berhubungan dengan kesehatan dan terdiri dari 211 data/record.
# Label yang mengklasifikasikan level obesitas berdasarkan pada rentang dari "underweight" hingga pada beberapa tipe obesitas yang berbeda.
#
# Banyak data yang dibuat melalui proses teknik sintetis, sementara beberapa data lainnya diambil langsung dari pengguna melalui web. Data ini bermanfaat untuk melakukan klasifikasi, regresi dan tugas pengelompokkan data/clustering.
#
# Beberapa variabel yang terdapat dalam dataset ini dan dapat dianalisis antara lain:
#
# 1. Gender : Laki-laki atau perempuan
# 2. Age : Usia dalam tahun
# 3. Height : Tinggi dalam meter
# 4. Weight : Bobot/Massa dalam Kilogram
# 5. family_history_with_overweight : Apakah orang tersebut memiliki riwayat dengan berat badan  berlebih(ya/tidak)
# 6. FAVC : Apakah seseorang sering mengkonsumsi makanan tinggi kalori (ya/tidak)
# 7. FCVC : Frekuensi mengkonsumsi buah-buahan (skala 1.sd. 3)
# 8. NCP : Jumlah makanan utama per hari
# 9. CAEC : Frekuensi mengkonsumsi cemilan diantara waktu makan (Tidak pernah, jarang, sering, selalu)
# 10. SMOKE : Apakah seseorang tersebut adalah perokok (ya/tidak)
# 11. CH2O : Konsumsi minum perhari (skala 1 s.d 3)
# 12. SCC : Apakah seseorang melakukan kontrol terhadap kalori harian(ya/tidak)
# 13. FAF : Frekuensi melakukan aktivitas fisik (skala 0 s.d 3)
# 14. TUE : Waktu dihabiskan menggunakan teknologi (skala 0 s.d 3)
# 15. CALC : Frekuensi mengkonsumsi alkohol (Tidak pernah, Jarang, Sering, Selalu)
# 16. MTRANS : Moda utama yang digunakan untuk transportasi (Mobil, Sepeda, Sepeda Motor, Transportasi umum, Jalan kaki)
# 17. NObeyesdad : Level Obesitas(Insufficient Weight, Normal Weight, Overweight Level I, Overweight Level II, Obesity Type I, Obesity Type II, Obesity Type III)
#
# Data ini memberikan pandangan yang terstruktur tentang bagaimana perbedaan gaya hidup mempengaruhi kepada tingkat obesitas seseorang, berguna dalam analisis kesehatan dan membuat keputusan.

# %% [markdown]
# ## 2.b Data Objective

# %% [markdown]
# Final Project 1 ini dibuat guna mengevaluasi konsep Machine Learning bertipe Klasifikasi dengan :
#
# ● Mampu memahami konsep Classification dengan Ensemble Model
#
# ● Mampu mempersiapkan data untuk digunakan dalam Ensemble Model
#
# ● Mampu mengimplementasikan Ensemble Model untuk membuat prediksi

# %% [markdown]
# # 3. Import Pustaka (Library)

# %%
# !pip install pandas-dq
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas-dq in c:\users\haziq razzan\appdata\roaming\python\python312\site-packages (1.29)
# Requirement already satisfied: numpy>=1.21.5 in c:\programdata\anaconda3\lib\site-packages (from pandas-dq) (1.26.4)
# Requirement already satisfied: pandas>=1.3.5 in c:\programdata\anaconda3\lib\site-packages (from pandas-dq) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\programdata\anaconda3\lib\site-packages (from pandas-dq) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.3.5->pandas-dq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.3.5->pandas-dq) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.3.5->pandas-dq) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->pandas-dq) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->pandas-dq) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->pandas-dq) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->pandas-dq) (1.16.0)

# %%
# !pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in c:\users\haziq razzan\appdata\roaming\python\python312\site-packages (0.19.5)
# Requirement already satisfied: branca>=0.6.0 in c:\users\haziq razzan\appdata\roaming\python\python312\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\programdata\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2024.8.30)

# %%
#untuk dataframe
import pandas as pd
import numpy as np

#untuk visualisasi data
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import folium
from folium.plugins import FastMarkerCluster

#mengatur display biar maximal
pd.options.display.max_rows = None
pd.options.display.max_columns = None

#modeling
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import ExtraTreesClassifier, VotingClassifier
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score # mencari accurasi 
from sklearn.metrics import confusion_matrix # membuat confusion maytris
from sklearn.metrics import classification_report # laporan klasifikasi
from sklearn.metrics import r2_score # evaluasi performa model
from sklearn.metrics import mean_squared_error # menghitung nilai error rata-rata
from imblearn.over_sampling import SMOTE #Balancing data
from sklearn.ensemble import BaggingClassifier, VotingClassifier, StackingClassifier
from pandas_dq import dq_report,Fix_DQ

# %% [markdown]
# # 4. Data Loading

# %% [markdown]
# ## 4.1 Memanggil Dataset

# %%
df = pd.read_csv("ObesityDataSet_raw_and_data_sinthetic.csv")
df.head(10)
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female  21    1.62    64.0                yes                no   2.0  3.0
# 1  Female  21    1.52    56.0                yes                no   3.0  3.0
# 2    Male  23    1.80    77.0                yes                no   2.0  3.0
# 3    Male  27    1.80    87.0                 no                no   3.0  3.0
# 4    Male  22    1.78    89.8                 no                no   2.0  1.0
# 5    Male  29    1.62    53.0                 no               yes   2.0  3.0
# 6  Female  23    1.50    55.0                yes               yes   3.0  3.0
# 7    Male  22    1.64    53.0                 no                no   2.0  3.0
# 8    Male  24    1.78    64.0                yes               yes   3.0  3.0
# 9    Male  22    1.72    68.0                yes               yes   2.0  3.0
#
#      CAEC    SMOKE  CH2O SCC   FAF  TUE     CALC            MTRANS          \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
# 5  Sometimes    no   2.0   no  0.0  0.0   Sometimes             Automobile
# 6  Sometimes    no   2.0   no  1.0  0.0   Sometimes              Motorbike
# 7  Sometimes    no   2.0   no  3.0  0.0   Sometimes  Public_Transportation
# 8  Sometimes    no   2.0   no  1.0  1.0  Frequently  Public_Transportation
# 9  Sometimes    no   2.0   no  1.0  1.0          no  Public_Transportation
#
#        NObeyesdad
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# 4  Overweight_Level_II
# 5        Normal_Weight
# 6        Normal_Weight
# 7        Normal_Weight
# 8        Normal_Weight
# 9        Normal_Weight

# %% [markdown]
# ## 4.2 Melihat ukuran/dimensi data (baris,kolom)

# %%
df.shape
# Out:
# (2111, 17)

# %% [markdown]
# ## 4.3 Pengecekan nama kolom

# %%
da = df.columns.values
da
dc = pd.DataFrame({'Nama kolom':da})
dc
# Out:
#               Nama kolom
# 0                           Gender
# 1                              Age
# 2                           Height
# 3                           Weight
# 4   family_history_with_overweight
# 5                             FAVC
# 6                             FCVC
# 7                              NCP
# 8                             CAEC
# 9                            SMOKE
# 10                            CH2O
# 11                             SCC
# 12                             FAF
# 13                             TUE
# 14                            CALC
# 15                          MTRANS
# 16                      NObeyesdad

# %% [markdown]
# ## 4.4 Penjelasan per kolom

# %%
de = np.array(['Laki-laki atau perempuan',
               'Usia dalam tahun',
               'Tinggi dalam meter',
               'Bobot/Massa dalam Kilogram',
               'Apakah orang tersebut memiliki riwayat dengan berat badan berlebih(ya/tidak)',
               'Apakah seseorang sering mengkonsumsi makanan tinggi kalori (ya/tidak)',
               'Frekuensi mengkonsumsi buah-buahan (skala 1.sd. 3)',
               'Jumlah makanan utama per hari',
               'Frekuensi mengkonsumsi cemilan diantara waktu makan (Tidak pernah, jarang, sering, selalu)',
               'Apakah seseorang tersebut adalah perokok (ya/tidak)',
               'Konsumsi minum perhari (skala 1 s.d 3)',
               'Apakah seseorang melakukan kontrol terhadap kalori harian(ya/tidak)',
               'Frekuensi melakukan aktivitas fisik (skala 0 s.d 3)',
               'Waktu dihabiskan menggunakan teknologi (skala 0 s.d 3)',
               'Frekuensi mengkonsumsi alkohol (Tidak pernah, Jarang, Sering, Selalu)',
               'Moda utama yang digunakan untuk transportasi (Mobil, Sepeda, Sepeda Motor, Transportasi umum, Jalan kaki)',
               'Level Obesitas(Insufficient Weight, Normal Weight, Overweight Level I, Overweight Level II, Obesity Type I, Obesity Type II, Obesity Type III)'])

penjelasan = pd.DataFrame({'Nomor Kolom':np.arange(1,len(de) + 1,1),
                           'Nama Kolom':da,
                           'Penjelasan Kolom':de})
penjelasan.set_index('Nomor Kolom')
# Out:
#                        Nama Kolom            \
# Nomor Kolom
# 1                                    Gender
# 2                                       Age
# 3                                    Height
# 4                                    Weight
# 5            family_history_with_overweight
# 6                                      FAVC
# 7                                      FCVC
# 8                                       NCP
# 9                                      CAEC
# 10                                    SMOKE
# 11                                     CH2O
# 12                                      SCC
# 13                                      FAF
# 14                                      TUE
# 15                                     CALC
# 16                                   MTRANS
# 17                               NObeyesdad
#
#                                                                             Penjelasan Kolom
# Nomor Kolom
# 1                                                                                                                                  Laki-laki atau perempuan
# 2                                                                                                                                          Usia dalam tahun
# 3                                                                                                                                        Tinggi dalam meter
# 4                                                                                                                                Bobot/Massa dalam Kilogram
# 5                                                                              Apakah orang tersebut memiliki riwayat dengan berat badan berlebih(ya/tidak)
# 6                                                                                     Apakah seseorang sering mengkonsumsi makanan tinggi kalori (ya/tidak)
# 7                                                                                                        Frekuensi mengkonsumsi buah-buahan (skala 1.sd. 3)
# 8                                                                                                                             Jumlah makanan utama per hari
# 9                                                                Frekuensi mengkonsumsi cemilan diantara waktu makan (Tidak pernah, jarang, sering, selalu)
# 10                                                                                                      Apakah seseorang tersebut adalah perokok (ya/tidak)
# 11                                                                                                                   Konsumsi minum perhari (skala 1 s.d 3)
# 12                                                                                      Apakah seseorang melakukan kontrol terhadap kalori harian(ya/tidak)
# 13                                                                                                      Frekuensi melakukan aktivitas fisik (skala 0 s.d 3)
# 14                                                                                                   Waktu dihabiskan menggunakan teknologi (skala 0 s.d 3)
# 15                                                                                    Frekuensi mengkonsumsi alkohol (Tidak pernah, Jarang, Sering, Selalu)
# 16                                                Moda utama yang digunakan untuk transportasi (Mobil, Sepeda, Sepeda Motor, Transportasi umum, Jalan kaki)
# 17           Level Obesitas(Insufficient Weight, Normal Weight, Overweight Level I, Overweight Level II, Obesity Type I, Obesity Type II, Obesity Type III)

# %% [markdown]
# ## 4.5 Tipe Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   int64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
#  12  FAF                             2111 non-null   float64
#  13  TUE                             2111 non-null   float64
#  14  CALC                            2111 non-null   object
#  15  MTRANS                          2111 non-null   object
#  16  NObeyesdad                      2111 non-null   object
# dtypes: float64(7), int64(1), object(9)
# memory usage: 280.5+ KB

# %% [markdown]
# ## 4.6 Deskriptif Statistik

# %%
df.describe()
# Out:
#            Age        Height       Weight        FCVC          NCP      \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.315964     1.701620    86.586035     2.418986     2.685651
# std       6.357078     0.093368    26.191163     0.533996     0.778079
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      20.000000     1.630000    65.470000     2.000000     2.660000
# 50%      23.000000     1.700000    83.000000     2.390000     3.000000
# 75%      26.000000     1.770000   107.430000     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#           CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008053     1.010313     0.657861
# std       0.612950     0.850613     0.608926
# min       1.000000     0.000000     0.000000
# 25%       1.585000     0.125000     0.000000
# 50%       2.000000     1.000000     0.625000
# 75%       2.480000     1.670000     1.000000
# max       3.000000     3.000000     2.000000

# %% [markdown]
# ## 4.7 Pengecekan Missing Value

# %%
df.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %% [markdown]
# karena data yang diperoleh dari awal sudah tidak memiliki "missing values" maka kita bisa melewatkan step untuk pembersihan missing value.

# %% [markdown]
# ## 4.8 Pengecekan data duplikat

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df[df.duplicated()].head()
# Out:
#      Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 98   Female  21    1.52    42.0                no                 no   3.0
# 106  Female  25    1.57    55.0                no                yes   2.0
# 174    Male  21    1.62    70.0                no                yes   2.0
# 179    Male  21    1.62    70.0                no                yes   2.0
# 184    Male  21    1.62    70.0                no                yes   2.0
#
#      NCP     CAEC    SMOKE  CH2O SCC  FAF  TUE    CALC     \
# 98   1.0  Frequently   no    1.0  no  0.0  0.0  Sometimes
# 106  1.0   Sometimes   no    2.0  no  2.0  0.0  Sometimes
# 174  1.0          no   no    3.0  no  1.0  0.0  Sometimes
# 179  1.0          no   no    3.0  no  1.0  0.0  Sometimes
# 184  1.0          no   no    3.0  no  1.0  0.0  Sometimes
#
#             MTRANS              NObeyesdad
# 98   Public_Transportation  Insufficient_Weight
# 106  Public_Transportation        Normal_Weight
# 174  Public_Transportation   Overweight_Level_I
# 179  Public_Transportation   Overweight_Level_I
# 184  Public_Transportation   Overweight_Level_I

# %% [markdown]
# setelah kita melakukan peninjauan terhadap data yang terindikasi duplikat, ternyata data tersebut bukanlah data duplikat melainkan **data yang memiliki identitas yang mirip tetapi memiliki nilai yang berbeda pada beberapa variabel**, dan berdasarkan hasil preview tersebut dapat disimpulkan bahwa data yang terindikasi duplikat adalah data yang berbeda (unik).

# %% [markdown]
# # 5. Eksplorasi Data Analisis

# %% [markdown]
# ## Deskripsi

# %%
# Melihat sebaran data dari jenis obesitas 
panjang = len(df["NObeyesdad"].unique())
jenis = {'Nomor': np.arange(1,panjang+1,1),
         'jenis': np.array(df["NObeyesdad"].unique()),
         'jumlah': np.array(df["NObeyesdad"].value_counts())
        }
jenis
jo = pd.DataFrame(jenis)
jo.set_index('Nomor')
# Out:
#              jenis          jumlah
# Nomor
# 1            Normal_Weight    351
# 2       Overweight_Level_I    324
# 3      Overweight_Level_II    297
# 4           Obesity_Type_I    290
# 5      Insufficient_Weight    290
# 6          Obesity_Type_II    287
# 7         Obesity_Type_III    272

# %%
# Menghitung jumlah kemunculan setiap nilai dalam kolom "Kematian" dalam DataFrame "df"
value_counts = df["NObeyesdad"].value_counts()

# Membuat grafik batang dengan menggunakan fungsi plot()

value_counts.plot(kind="bar", color = 'Blue')

# Annotate data points with labels
x = jo["jenis"]
y = jo["jumlah"]

plt.plot(x,y,marker='o')

# Menambahkan data label
for i, value in enumerate(y):
    plt.text(i, value + 0.1, str(value), ha='center')

# Memberikan judul pada grafik
plt.title("Perbandingan nilai pada kolom Obesitas")

# Memberikan label sumbu x
plt.xlabel("Jenis Obesitas")

# Memberikan label sumbu y
plt.ylabel("Jumlah")

# Menampilkan jumlah kemunculan setiap nilai pada kolom "Jenis Obesitas"
print(value_counts)

# Memunculkan Grafik 
plt.show()
# Out:
# NObeyesdad
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: count, dtype: int64

# %% [markdown]
# ## 5.1 Kesimpulan

# %% [markdown]
# dari grafik batang diatas dapat disimpulkan bahwa jenis obesitas yang paling terjadi adalah Obesity_TypeI sebanyak 351 Kejadian, dan jenis obesitas yang paling rendah terjadi adalah insufficient_weight dengan jumlah kejadian sebanyak 272 kejadian.
#
# Kolom **"NObeyesdad"** atau kolom **Jenis Obesitas** akan dijadikan kolom target, dan dari grafik diatas dapat terlihat bahwa kolom ini memiliki kelas yang sebarannya tidak merat, yaitu salah satu kelas lebih sedikit dibandingkan dengan kelas lainnya, hal ini dapat dipertimbangkan apakah perlu dilakukan balancing/resampling untuk data ini.

# %% [markdown]
# ## 5.2 Catplot

# %% [markdown]
# Untuk menampilkan hubungan antara kolom penyebab/independen dengan kolom target/dependen, dapat dilihat hubungannya melalui grafik batang yang akan ditampilkan

# %%
penjelasan
# Out:
#     Nomor Kolom            Nama Kolom            \
# 0        1                               Gender
# 1        2                                  Age
# 2        3                               Height
# 3        4                               Weight
# 4        5       family_history_with_overweight
# 5        6                                 FAVC
# 6        7                                 FCVC
# 7        8                                  NCP
# 8        9                                 CAEC
# 9       10                                SMOKE
# 10      11                                 CH2O
# 11      12                                  SCC
# 12      13                                  FAF
# 13      14                                  TUE
# 14      15                                 CALC
# 15      16                               MTRANS
# 16      17                           NObeyesdad
#
#                                                                    Penjelasan Kolom
# 0                                                                                                                         Laki-laki atau perempuan
# 1                                                                                                                                 Usia dalam tahun
# 2                                                                                                                               Tinggi dalam meter
# 3                                                                                                                       Bobot/Massa dalam Kilogram
# 4                                                                     Apakah orang tersebut memiliki riwayat dengan berat badan berlebih(ya/tidak)
# 5                                                                            Apakah seseorang sering mengkonsumsi makanan tinggi kalori (ya/tidak)
# 6                                                                                               Frekuensi mengkonsumsi buah-buahan (skala 1.sd. 3)
# 7                                                                                                                    Jumlah makanan utama per hari
# 8                                                       Frekuensi mengkonsumsi cemilan diantara waktu makan (Tidak pernah, jarang, sering, selalu)
# 9                                                                                              Apakah seseorang tersebut adalah perokok (ya/tidak)
# 10                                                                                                          Konsumsi minum perhari (skala 1 s.d 3)
# 11                                                                             Apakah seseorang melakukan kontrol terhadap kalori harian(ya/tidak)
# 12                                                                                             Frekuensi melakukan aktivitas fisik (skala 0 s.d 3)
# 13                                                                                          Waktu dihabiskan menggunakan teknologi (skala 0 s.d 3)
# 14                                                                           Frekuensi mengkonsumsi alkohol (Tidak pernah, Jarang, Sering, Selalu)
# 15                                       Moda utama yang digunakan untuk transportasi (Mobil, Sepeda, Sepeda Motor, Transportasi umum, Jalan kaki)
# 16  Level Obesitas(Insufficient Weight, Normal Weight, Overweight Level I, Overweight Level II, Obesity Type I, Obesity Type II, Obesity Type III)

# %% [markdown]
# ### 5.2.a membandingkan kolom "Jenis Obesitas" dengan "Jenis Kelamin"

# %%
df[['NObeyesdad','Gender']]
# Out:
#           NObeyesdad       Gender
# 0           Normal_Weight  Female
# 1           Normal_Weight  Female
# 2           Normal_Weight    Male
# 3      Overweight_Level_I    Male
# 4     Overweight_Level_II    Male
# 5           Normal_Weight    Male
# 6           Normal_Weight  Female
# 7           Normal_Weight    Male
# 8           Normal_Weight    Male
# 9           Normal_Weight    Male
# 10         Obesity_Type_I    Male
# 11    Overweight_Level_II  Female
# 12          Normal_Weight    Male
# 13         Obesity_Type_I    Male
# 14          Normal_Weight    Male
# 15          Normal_Weight  Female
# 16    Overweight_Level_II    Male
# 17         Obesity_Type_I  Female
# 18    Overweight_Level_II  Female
# 19     Overweight_Level_I  Female
# 20    Overweight_Level_II    Male
# 21         Obesity_Type_I  Female
# 22          Normal_Weight  Female
# 23         Obesity_Type_I  Female
# 24          Normal_Weight    Male
# 25          Normal_Weight    Male
# 26          Normal_Weight    Male
# 27          Normal_Weight  Female
# 28          Normal_Weight    Male
# 29          Normal_Weight    Male
# 30     Overweight_Level_I    Male
# 31    Overweight_Level_II  Female
# 32          Normal_Weight  Female
# 33    Overweight_Level_II    Male
# 34          Normal_Weight    Male
# 35    Overweight_Level_II  Female
# 36          Normal_Weight  Female
# 37          Normal_Weight  Female
# 38          Normal_Weight    Male
# 39    Overweight_Level_II  Female
# 40     Overweight_Level_I  Female
# 41          Normal_Weight    Male
# 42          Normal_Weight  Female
# 43          Normal_Weight    Male
# 44          Normal_Weight    Male
# 45    Overweight_Level_II  Female
# 46          Normal_Weight    Male
# 47          Normal_Weight    Male
# 48          Normal_Weight  Female
# 49          Normal_Weight  Female
# 50          Normal_Weight  Female
# 51          Normal_Weight  Female
# 52          Normal_Weight  Female
# 53          Normal_Weight  Female
# 54          Normal_Weight  Female
# 55          Normal_Weight    Male
# 56          Normal_Weight    Male
# 57          Normal_Weight    Male
# 58          Normal_Weight  Female
# 59    Insufficient_Weight    Male
# 60          Normal_Weight  Female
# 61          Normal_Weight    Male
# 62          Normal_Weight    Male
# 63          Normal_Weight    Male
# 64          Normal_Weight  Female
# 65     Overweight_Level_I  Female
# 66    Overweight_Level_II    Male
# 67         Obesity_Type_I    Male
# 68        Obesity_Type_II    Male
# 69          Normal_Weight    Male
# 70    Overweight_Level_II  Female
# 71    Insufficient_Weight  Female
# 72          Normal_Weight  Female
# 73          Normal_Weight    Male
# 74    Overweight_Level_II    Male
# 75    Insufficient_Weight  Female
# 76    Insufficient_Weight  Female
# 77    Overweight_Level_II  Female
# 78         Obesity_Type_I  Female
# 79          Normal_Weight    Male
# 80          Normal_Weight  Female
# 81    Overweight_Level_II    Male
# 82         Obesity_Type_I    Male
# 83    Insufficient_Weight  Female
# 84    Overweight_Level_II    Male
# 85          Normal_Weight    Male
# 86          Normal_Weight    Male
# 87     Overweight_Level_I    Male
# 88          Normal_Weight  Female
# 89    Overweight_Level_II  Female
# 90        Obesity_Type_II  Female
# 91          Normal_Weight  Female
# 92     Overweight_Level_I    Male
# 93          Normal_Weight  Female
# 94          Normal_Weight  Female
# 95          Normal_Weight    Male
# 96          Normal_Weight  Female
# 97    Insufficient_Weight  Female
# 98    Insufficient_Weight  Female
# 99          Normal_Weight    Male
# 100         Normal_Weight  Female
# 101         Normal_Weight    Male
# 102         Normal_Weight  Female
# 103         Normal_Weight  Female
# 104        Obesity_Type_I  Female
# 105         Normal_Weight  Female
# 106         Normal_Weight  Female
# 107    Overweight_Level_I    Male
# 108        Obesity_Type_I    Male
# 109        Obesity_Type_I  Female
# 110         Normal_Weight    Male
# 111         Normal_Weight  Female
# 112         Normal_Weight  Female
# 113         Normal_Weight  Female
# 114         Normal_Weight  Female
# 115         Normal_Weight  Female
# 116        Obesity_Type_I  Female
# 117   Overweight_Level_II  Female
# 118         Normal_Weight    Male
# 119   Overweight_Level_II  Female
# 120    Overweight_Level_I  Female
# 121   Overweight_Level_II    Male
# 122   Insufficient_Weight    Male
# 123         Normal_Weight    Male
# 124   Overweight_Level_II    Male
# 125    Overweight_Level_I    Male
# 126         Normal_Weight    Male
# 127         Normal_Weight  Female
# 128         Normal_Weight    Male
# 129   Overweight_Level_II    Male
# 130         Normal_Weight  Female
# 131         Normal_Weight    Male
# 132         Normal_Weight  Female
# 133         Normal_Weight  Female
# 134        Obesity_Type_I    Male
# 135    Overweight_Level_I    Male
# 136         Normal_Weight    Male
# 137        Obesity_Type_I    Male
# 138         Normal_Weight    Male
# 139         Normal_Weight    Male
# 140   Insufficient_Weight    Male
# 141         Normal_Weight    Male
# 142        Obesity_Type_I    Male
# 143    Overweight_Level_I  Female
# 144    Overweight_Level_I    Male
# 145    Overweight_Level_I    Male
# 146         Normal_Weight  Female
# 147        Obesity_Type_I  Female
# 148         Normal_Weight  Female
# 149        Obesity_Type_I  Female
# 150         Normal_Weight    Male
# 151         Normal_Weight  Female
# 152    Overweight_Level_I  Female
# 153   Overweight_Level_II    Male
# 154        Obesity_Type_I    Male
# 155         Normal_Weight  Female
# 156         Normal_Weight  Female
# 157         Normal_Weight    Male
# 158    Overweight_Level_I  Female
# 159   Overweight_Level_II    Male
# 160         Normal_Weight    Male
# 161   Overweight_Level_II    Male
# 162         Normal_Weight  Female
# 163         Normal_Weight    Male
# 164   Overweight_Level_II    Male
# 165       Obesity_Type_II    Male
# 166         Normal_Weight  Female
# 167   Overweight_Level_II    Male
# 168    Overweight_Level_I  Female
# 169   Overweight_Level_II  Female
# 170   Overweight_Level_II    Male
# 171         Normal_Weight    Male
# 172         Normal_Weight  Female
# 173         Normal_Weight    Male
# 174    Overweight_Level_I    Male
# 175         Normal_Weight  Female
# 176         Normal_Weight  Female
# 177         Normal_Weight    Male
# 178         Normal_Weight    Male
# 179    Overweight_Level_I    Male
# 180         Normal_Weight  Female
# 181         Normal_Weight  Female
# 182   Insufficient_Weight  Female
# 183   Overweight_Level_II  Female
# 184    Overweight_Level_I    Male
# 185    Overweight_Level_I  Female
# 186        Obesity_Type_I    Male
# 187        Obesity_Type_I    Male
# 188        Obesity_Type_I    Male
# 189         Normal_Weight  Female
# 190         Normal_Weight    Male
# 191    Overweight_Level_I    Male
# 192    Overweight_Level_I    Male
# 193         Normal_Weight    Male
# 194        Obesity_Type_I  Female
# 195    Overweight_Level_I    Male
# 196         Normal_Weight    Male
# 197       Obesity_Type_II    Male
# 198   Insufficient_Weight  Female
# 199         Normal_Weight  Female
# 200        Obesity_Type_I  Female
# 201        Obesity_Type_I  Female
# 202      Obesity_Type_III  Female
# 203        Obesity_Type_I    Male
# 204         Normal_Weight    Male
# 205        Obesity_Type_I  Female
# 206        Obesity_Type_I    Male
# 207         Normal_Weight    Male
# 208         Normal_Weight  Female
# 209         Normal_Weight  Female
# 210       Obesity_Type_II    Male
# 211         Normal_Weight  Female
# 212   Overweight_Level_II  Female
# 213         Normal_Weight    Male
# 214         Normal_Weight    Male
# 215         Normal_Weight    Male
# 216         Normal_Weight  Female
# 217    Overweight_Level_I    Male
# 218         Normal_Weight  Female
# 219    Overweight_Level_I  Female
# 220    Overweight_Level_I  Female
# 221   Overweight_Level_II    Male
# 222         Normal_Weight  Female
# 223         Normal_Weight  Female
# 224        Obesity_Type_I  Female
# 225       Obesity_Type_II    Male
# 226         Normal_Weight  Female
# 227         Normal_Weight  Female
# 228   Overweight_Level_II  Female
# 229       Obesity_Type_II    Male
# 230    Overweight_Level_I    Male
# 231         Normal_Weight  Female
# 232         Normal_Weight  Female
# 233   Overweight_Level_II  Female
# 234         Normal_Weight  Female
# 235         Normal_Weight  Female
# 236         Normal_Weight  Female
# 237         Normal_Weight  Female
# 238         Normal_Weight  Female
# 239         Normal_Weight  Female
# 240         Normal_Weight  Female
# 241    Overweight_Level_I    Male
# 242         Normal_Weight  Female
# 243   Overweight_Level_II    Male
# 244         Normal_Weight  Female
# 245   Insufficient_Weight  Female
# 246         Normal_Weight  Female
# 247         Normal_Weight  Female
# 248         Normal_Weight    Male
# 249    Overweight_Level_I    Male
# 250   Overweight_Level_II  Female
# 251   Overweight_Level_II    Male
# 252   Overweight_Level_II    Male
# 253         Normal_Weight  Female
# 254         Normal_Weight  Female
# 255    Overweight_Level_I    Male
# 256   Overweight_Level_II    Male
# 257        Obesity_Type_I    Male
# 258   Overweight_Level_II    Male
# 259        Obesity_Type_I  Female
# 260    Overweight_Level_I    Male
# 261    Overweight_Level_I  Female
# 262         Normal_Weight    Male
# 263   Insufficient_Weight    Male
# 264         Normal_Weight    Male
# 265   Insufficient_Weight    Male
# 266   Insufficient_Weight  Female
# 267   Overweight_Level_II    Male
# 268         Normal_Weight    Male
# 269         Normal_Weight    Male
# 270        Obesity_Type_I    Male
# 271         Normal_Weight  Female
# 272         Normal_Weight    Male
# 273         Normal_Weight    Male
# 274         Normal_Weight  Female
# 275         Normal_Weight  Female
# 276   Insufficient_Weight    Male
# 277         Normal_Weight    Male
# 278         Normal_Weight  Female
# 279   Insufficient_Weight    Male
# 280         Normal_Weight    Male
# 281         Normal_Weight    Male
# 282         Normal_Weight  Female
# 283         Normal_Weight    Male
# 284         Normal_Weight    Male
# 285        Obesity_Type_I    Male
# 286         Normal_Weight  Female
# 287         Normal_Weight  Female
# 288         Normal_Weight  Female
# 289         Normal_Weight    Male
# 290         Normal_Weight    Male
# 291   Insufficient_Weight    Male
# 292         Normal_Weight    Male
# 293         Normal_Weight    Male
# 294        Obesity_Type_I    Male
# 295         Normal_Weight  Female
# 296         Normal_Weight  Female
# 297    Overweight_Level_I    Male
# 298         Normal_Weight    Male
# 299    Overweight_Level_I    Male
# 300         Normal_Weight    Male
# 301         Normal_Weight    Male
# 302   Insufficient_Weight    Male
# 303         Normal_Weight  Female
# 304    Overweight_Level_I    Male
# 305       Obesity_Type_II    Male
# 306         Normal_Weight  Female
# 307         Normal_Weight  Female
# 308         Normal_Weight    Male
# 309         Normal_Weight  Female
# 310   Insufficient_Weight    Male
# 311         Normal_Weight    Male
# 312         Normal_Weight  Female
# 313         Normal_Weight    Male
# 314         Normal_Weight  Female
# 315         Normal_Weight    Male
# 316         Normal_Weight    Male
# 317         Normal_Weight    Male
# 318         Normal_Weight  Female
# 319    Overweight_Level_I  Female
# 320         Normal_Weight    Male
# 321         Normal_Weight    Male
# 322   Insufficient_Weight  Female
# 323         Normal_Weight    Male
# 324    Overweight_Level_I  Female
# 325         Normal_Weight  Female
# 326         Normal_Weight    Male
# 327    Overweight_Level_I    Male
# 328         Normal_Weight    Male
# 329        Obesity_Type_I  Female
# 330   Insufficient_Weight  Female
# 331         Normal_Weight    Male
# 332         Normal_Weight    Male
# 333         Normal_Weight  Female
# 334    Overweight_Level_I  Female
# 335   Insufficient_Weight    Male
# 336         Normal_Weight    Male
# 337         Normal_Weight    Male
# 338    Overweight_Level_I  Female
# 339   Insufficient_Weight  Female
# 340         Normal_Weight    Male
# 341         Normal_Weight    Male
# 342        Obesity_Type_I    Male
# 343         Normal_Weight    Male
# 344      Obesity_Type_III    Male
# 345         Normal_Weight    Male
# 346         Normal_Weight  Female
# 347   Overweight_Level_II    Male
# 348         Normal_Weight    Male
# 349        Obesity_Type_I    Male
# 350         Normal_Weight    Male
# 351         Normal_Weight  Female
# 352         Normal_Weight  Female
# 353         Normal_Weight  Female
# 354         Normal_Weight  Female
# 355    Overweight_Level_I  Female
# 356   Insufficient_Weight    Male
# 357         Normal_Weight  Female
# 358       Obesity_Type_II    Male
# 359         Normal_Weight  Female
# 360         Normal_Weight    Male
# 361        Obesity_Type_I  Female
# 362    Overweight_Level_I  Female
# 363         Normal_Weight    Male
# 364    Overweight_Level_I    Male
# 365         Normal_Weight    Male
# 366   Overweight_Level_II    Male
# 367    Overweight_Level_I  Female
# 368   Overweight_Level_II  Female
# 369   Overweight_Level_II    Male
# 370         Normal_Weight    Male
# 371    Overweight_Level_I    Male
# 372         Normal_Weight  Female
# 373         Normal_Weight  Female
# 374         Normal_Weight    Male
# 375   Overweight_Level_II    Male
# 376         Normal_Weight  Female
# 377         Normal_Weight    Male
# 378         Normal_Weight    Male
# 379         Normal_Weight    Male
# 380   Overweight_Level_II    Male
# 381         Normal_Weight    Male
# 382         Normal_Weight  Female
# 383        Obesity_Type_I    Male
# 384         Normal_Weight  Female
# 385         Normal_Weight  Female
# 386         Normal_Weight  Female
# 387        Obesity_Type_I  Female
# 388        Obesity_Type_I    Male
# 389    Overweight_Level_I  Female
# 390   Insufficient_Weight    Male
# 391   Insufficient_Weight  Female
# 392         Normal_Weight    Male
# 393   Overweight_Level_II    Male
# 394         Normal_Weight  Female
# 395   Insufficient_Weight  Female
# 396         Normal_Weight  Female
# 397         Normal_Weight    Male
# 398       Obesity_Type_II    Male
# 399         Normal_Weight    Male
# 400    Overweight_Level_I    Male
# 401         Normal_Weight    Male
# 402   Overweight_Level_II    Male
# 403      Obesity_Type_III  Female
# 404         Normal_Weight    Male
# 405   Overweight_Level_II    Male
# 406         Normal_Weight    Male
# 407    Overweight_Level_I  Female
# 408         Normal_Weight    Male
# 409         Normal_Weight  Female
# 410         Normal_Weight    Male
# 411    Overweight_Level_I  Female
# 412         Normal_Weight    Male
# 413   Overweight_Level_II    Male
# 414        Obesity_Type_I    Male
# 415         Normal_Weight    Male
# 416    Overweight_Level_I    Male
# 417   Overweight_Level_II    Male
# 418        Obesity_Type_I    Male
# 419        Obesity_Type_I    Male
# 420   Insufficient_Weight    Male
# 421   Insufficient_Weight    Male
# 422         Normal_Weight    Male
# 423   Overweight_Level_II    Male
# 424    Overweight_Level_I    Male
# 425         Normal_Weight  Female
# 426         Normal_Weight    Male
# 427         Normal_Weight  Female
# 428         Normal_Weight    Male
# 429         Normal_Weight    Male
# 430        Obesity_Type_I    Male
# 431         Normal_Weight  Female
# 432         Normal_Weight    Male
# 433         Normal_Weight  Female
# 434         Normal_Weight    Male
# 435    Overweight_Level_I  Female
# 436         Normal_Weight  Female
# 437         Normal_Weight  Female
# 438         Normal_Weight  Female
# 439         Normal_Weight  Female
# 440         Normal_Weight  Female
# 441         Normal_Weight  Female
# 442         Normal_Weight    Male
# 443   Insufficient_Weight    Male
# 444         Normal_Weight    Male
# 445         Normal_Weight  Female
# 446         Normal_Weight    Male
# 447    Overweight_Level_I    Male
# 448       Obesity_Type_II  Female
# 449         Normal_Weight  Female
# 450         Normal_Weight    Male
# 451         Normal_Weight    Male
# 452         Normal_Weight    Male
# 453         Normal_Weight  Female
# 454         Normal_Weight  Female
# 455         Normal_Weight    Male
# 456         Normal_Weight  Female
# 457         Normal_Weight  Female
# 458         Normal_Weight    Male
# 459    Overweight_Level_I    Male
# 460         Normal_Weight  Female
# 461        Obesity_Type_I    Male
# 462   Overweight_Level_II    Male
# 463         Normal_Weight    Male
# 464         Normal_Weight    Male
# 465         Normal_Weight  Female
# 466         Normal_Weight    Male
# 467         Normal_Weight    Male
# 468   Insufficient_Weight  Female
# 469   Insufficient_Weight  Female
# 470         Normal_Weight  Female
# 471        Obesity_Type_I  Female
# 472   Overweight_Level_II  Female
# 473         Normal_Weight  Female
# 474         Normal_Weight    Male
# 475    Overweight_Level_I  Female
# 476    Overweight_Level_I  Female
# 477         Normal_Weight  Female
# 478         Normal_Weight    Male
# 479         Normal_Weight  Female
# 480         Normal_Weight  Female
# 481         Normal_Weight    Male
# 482         Normal_Weight  Female
# 483    Overweight_Level_I  Female
# 484   Overweight_Level_II  Female
# 485         Normal_Weight    Male
# 486         Normal_Weight    Male
# 487        Obesity_Type_I    Male
# 488         Normal_Weight    Male
# 489         Normal_Weight  Female
# 490   Overweight_Level_II    Male
# 491         Normal_Weight    Male
# 492   Overweight_Level_II    Male
# 493         Normal_Weight    Male
# 494         Normal_Weight  Female
# 495         Normal_Weight    Male
# 496   Insufficient_Weight    Male
# 497         Normal_Weight    Male
# 498      Obesity_Type_III  Female
# 499      Obesity_Type_III  Female
# 500      Obesity_Type_III  Female
# 501      Obesity_Type_III  Female
# 502      Obesity_Type_III  Female
# 503      Obesity_Type_III  Female
# 504      Obesity_Type_III  Female
# 505      Obesity_Type_III  Female
# 506      Obesity_Type_III  Female
# 507   Insufficient_Weight    Male
# 508   Insufficient_Weight    Male
# 509   Insufficient_Weight    Male
# 510   Insufficient_Weight  Female
# 511   Insufficient_Weight  Female
# 512   Insufficient_Weight  Female
# 513   Insufficient_Weight  Female
# 514   Insufficient_Weight  Female
# 515   Insufficient_Weight  Female
# 516   Insufficient_Weight  Female
# 517   Insufficient_Weight  Female
# 518   Insufficient_Weight  Female
# 519   Insufficient_Weight  Female
# 520   Insufficient_Weight  Female
# 521   Insufficient_Weight  Female
# 522   Insufficient_Weight  Female
# 523   Insufficient_Weight  Female
# 524   Insufficient_Weight  Female
# 525   Insufficient_Weight  Female
# 526   Insufficient_Weight  Female
# 527   Insufficient_Weight  Female
# 528   Insufficient_Weight  Female
# 529   Insufficient_Weight  Female
# 530   Insufficient_Weight  Female
# 531   Insufficient_Weight    Male
# 532   Insufficient_Weight    Male
# 533   Insufficient_Weight    Male
# 534   Insufficient_Weight    Male
# 535   Insufficient_Weight    Male
# 536   Insufficient_Weight    Male
# 537   Insufficient_Weight  Female
# 538   Insufficient_Weight  Female
# 539   Insufficient_Weight  Female
# 540   Insufficient_Weight  Female
# 541   Insufficient_Weight  Female
# 542   Insufficient_Weight  Female
# 543   Insufficient_Weight  Female
# 544   Insufficient_Weight  Female
# 545   Insufficient_Weight  Female
# 546   Insufficient_Weight  Female
# 547   Insufficient_Weight  Female
# 548   Insufficient_Weight  Female
# 549   Insufficient_Weight  Female
# 550   Insufficient_Weight  Female
# 551   Insufficient_Weight  Female
# 552   Insufficient_Weight    Male
# 553   Insufficient_Weight    Male
# 554   Insufficient_Weight    Male
# 555   Insufficient_Weight    Male
# 556   Insufficient_Weight    Male
# 557   Insufficient_Weight    Male
# 558   Insufficient_Weight    Male
# 559   Insufficient_Weight    Male
# 560   Insufficient_Weight    Male
# 561   Insufficient_Weight  Female
# 562   Insufficient_Weight  Female
# 563   Insufficient_Weight  Female
# 564   Insufficient_Weight    Male
# 565   Insufficient_Weight    Male
# 566   Insufficient_Weight    Male
# 567   Insufficient_Weight  Female
# 568   Insufficient_Weight  Female
# 569   Insufficient_Weight  Female
# 570   Insufficient_Weight  Female
# 571   Insufficient_Weight  Female
# 572   Insufficient_Weight  Female
# 573   Insufficient_Weight  Female
# 574   Insufficient_Weight  Female
# 575   Insufficient_Weight  Female
# 576   Insufficient_Weight  Female
# 577   Insufficient_Weight  Female
# 578   Insufficient_Weight  Female
# 579   Insufficient_Weight    Male
# 580   Insufficient_Weight    Male
# 581   Insufficient_Weight    Male
# 582   Insufficient_Weight  Female
# 583   Insufficient_Weight  Female
# 584   Insufficient_Weight  Female
# 585   Insufficient_Weight  Female
# 586   Insufficient_Weight  Female
# 587   Insufficient_Weight  Female
# 588   Insufficient_Weight  Female
# 589   Insufficient_Weight  Female
# 590   Insufficient_Weight  Female
# 591   Insufficient_Weight    Male
# 592   Insufficient_Weight    Male
# 593   Insufficient_Weight    Male
# 594   Insufficient_Weight    Male
# 595   Insufficient_Weight    Male
# 596   Insufficient_Weight    Male
# 597   Insufficient_Weight    Male
# 598   Insufficient_Weight    Male
# 599   Insufficient_Weight    Male
# 600   Insufficient_Weight  Female
# 601   Insufficient_Weight  Female
# 602   Insufficient_Weight  Female
# 603   Insufficient_Weight  Female
# 604   Insufficient_Weight  Female
# 605   Insufficient_Weight  Female
# 606   Insufficient_Weight    Male
# 607   Insufficient_Weight    Male
# 608   Insufficient_Weight    Male
# 609   Insufficient_Weight    Male
# 610   Insufficient_Weight  Female
# 611   Insufficient_Weight  Female
# 612   Insufficient_Weight  Female
# 613   Insufficient_Weight  Female
# 614   Insufficient_Weight  Female
# 615   Insufficient_Weight  Female
# 616   Insufficient_Weight  Female
# 617   Insufficient_Weight    Male
# 618   Insufficient_Weight  Female
# 619   Insufficient_Weight  Female
# 620   Insufficient_Weight  Female
# 621   Insufficient_Weight  Female
# 622   Insufficient_Weight  Female
# 623   Insufficient_Weight  Female
# 624   Insufficient_Weight    Male
# 625   Insufficient_Weight    Male
# 626   Insufficient_Weight    Male
# 627   Insufficient_Weight  Female
# 628   Insufficient_Weight    Male
# 629   Insufficient_Weight  Female
# 630   Insufficient_Weight  Female
# 631   Insufficient_Weight  Female
# 632   Insufficient_Weight  Female
# 633   Insufficient_Weight    Male
# 634   Insufficient_Weight  Female
# 635   Insufficient_Weight  Female
# 636   Insufficient_Weight  Female
# 637   Insufficient_Weight    Male
# 638   Insufficient_Weight    Male
# 639   Insufficient_Weight    Male
# 640   Insufficient_Weight  Female
# 641   Insufficient_Weight  Female
# 642   Insufficient_Weight    Male
# 643   Insufficient_Weight    Male
# 644   Insufficient_Weight    Male
# 645   Insufficient_Weight  Female
# 646   Insufficient_Weight  Female
# 647   Insufficient_Weight  Female
# 648   Insufficient_Weight  Female
# 649   Insufficient_Weight  Female
# 650   Insufficient_Weight  Female
# 651   Insufficient_Weight  Female
# 652   Insufficient_Weight  Female
# 653   Insufficient_Weight  Female
# 654   Insufficient_Weight  Female
# 655   Insufficient_Weight  Female
# 656   Insufficient_Weight  Female
# 657   Insufficient_Weight  Female
# 658   Insufficient_Weight  Female
# 659   Insufficient_Weight  Female
# 660   Insufficient_Weight  Female
# 661   Insufficient_Weight  Female
# 662   Insufficient_Weight  Female
# 663   Insufficient_Weight  Female
# 664   Insufficient_Weight  Female
# 665   Insufficient_Weight  Female
# 666   Insufficient_Weight  Female
# 667   Insufficient_Weight    Male
# 668   Insufficient_Weight    Male
# 669   Insufficient_Weight    Male
# 670   Insufficient_Weight    Male
# 671   Insufficient_Weight  Female
# 672   Insufficient_Weight    Male
# 673   Insufficient_Weight  Female
# 674   Insufficient_Weight  Female
# 675   Insufficient_Weight  Female
# 676   Insufficient_Weight  Female
# 677   Insufficient_Weight  Female
# 678   Insufficient_Weight  Female
# 679   Insufficient_Weight  Female
# 680   Insufficient_Weight    Male
# 681   Insufficient_Weight  Female
# 682   Insufficient_Weight  Female
# 683   Insufficient_Weight  Female
# 684   Insufficient_Weight  Female
# 685   Insufficient_Weight  Female
# 686   Insufficient_Weight  Female
# 687   Insufficient_Weight  Female
# 688   Insufficient_Weight    Male
# 689   Insufficient_Weight  Female
# 690   Insufficient_Weight    Male
# 691   Insufficient_Weight    Male
# 692   Insufficient_Weight    Male
# 693   Insufficient_Weight    Male
# 694   Insufficient_Weight    Male
# 695   Insufficient_Weight    Male
# 696   Insufficient_Weight    Male
# 697   Insufficient_Weight  Female
# 698   Insufficient_Weight  Female
# 699   Insufficient_Weight  Female
# 700   Insufficient_Weight    Male
# 701   Insufficient_Weight    Male
# 702   Insufficient_Weight    Male
# 703   Insufficient_Weight  Female
# 704   Insufficient_Weight    Male
# 705   Insufficient_Weight  Female
# 706   Insufficient_Weight  Female
# 707   Insufficient_Weight  Female
# 708   Insufficient_Weight  Female
# 709   Insufficient_Weight  Female
# 710   Insufficient_Weight  Female
# 711   Insufficient_Weight  Female
# 712   Insufficient_Weight  Female
# 713   Insufficient_Weight  Female
# 714   Insufficient_Weight  Female
# 715   Insufficient_Weight    Male
# 716   Insufficient_Weight    Male
# 717   Insufficient_Weight    Male
# 718   Insufficient_Weight  Female
# 719   Insufficient_Weight  Female
# 720   Insufficient_Weight  Female
# 721   Insufficient_Weight  Female
# 722   Insufficient_Weight  Female
# 723   Insufficient_Weight  Female
# 724   Insufficient_Weight  Female
# 725   Insufficient_Weight  Female
# 726   Insufficient_Weight  Female
# 727   Insufficient_Weight    Male
# 728   Insufficient_Weight    Male
# 729   Insufficient_Weight    Male
# 730   Insufficient_Weight    Male
# 731   Insufficient_Weight    Male
# 732   Insufficient_Weight    Male
# 733   Insufficient_Weight    Male
# 734   Insufficient_Weight    Male
# 735   Insufficient_Weight    Male
# 736   Insufficient_Weight  Female
# 737   Insufficient_Weight  Female
# 738   Insufficient_Weight  Female
# 739   Insufficient_Weight  Female
# 740   Insufficient_Weight  Female
# 741   Insufficient_Weight  Female
# 742   Insufficient_Weight    Male
# 743   Insufficient_Weight    Male
# 744   Insufficient_Weight    Male
# 745    Overweight_Level_I    Male
# 746    Overweight_Level_I    Male
# 747    Overweight_Level_I    Male
# 748    Overweight_Level_I    Male
# 749    Overweight_Level_I    Male
# 750    Overweight_Level_I    Male
# 751    Overweight_Level_I  Female
# 752    Overweight_Level_I    Male
# 753    Overweight_Level_I    Male
# 754    Overweight_Level_I  Female
# 755    Overweight_Level_I    Male
# 756    Overweight_Level_I  Female
# 757    Overweight_Level_I  Female
# 758    Overweight_Level_I    Male
# 759    Overweight_Level_I  Female
# 760    Overweight_Level_I  Female
# 761    Overweight_Level_I  Female
# 762    Overweight_Level_I    Male
# 763    Overweight_Level_I    Male
# 764    Overweight_Level_I    Male
# 765    Overweight_Level_I  Female
# 766    Overweight_Level_I    Male
# 767    Overweight_Level_I    Male
# 768    Overweight_Level_I    Male
# 769    Overweight_Level_I    Male
# 770    Overweight_Level_I    Male
# 771    Overweight_Level_I  Female
# 772    Overweight_Level_I    Male
# 773    Overweight_Level_I  Female
# 774    Overweight_Level_I  Female
# 775    Overweight_Level_I    Male
# 776    Overweight_Level_I    Male
# 777    Overweight_Level_I  Female
# 778    Overweight_Level_I    Male
# 779    Overweight_Level_I    Male
# 780    Overweight_Level_I    Male
# 781    Overweight_Level_I  Female
# 782    Overweight_Level_I  Female
# 783    Overweight_Level_I    Male
# 784    Overweight_Level_I  Female
# 785    Overweight_Level_I  Female
# 786    Overweight_Level_I  Female
# 787    Overweight_Level_I  Female
# 788    Overweight_Level_I    Male
# 789    Overweight_Level_I  Female
# 790    Overweight_Level_I    Male
# 791    Overweight_Level_I  Female
# 792    Overweight_Level_I  Female
# 793    Overweight_Level_I  Female
# 794    Overweight_Level_I  Female
# 795    Overweight_Level_I    Male
# 796    Overweight_Level_I  Female
# 797    Overweight_Level_I    Male
# 798    Overweight_Level_I    Male
# 799    Overweight_Level_I  Female
# 800    Overweight_Level_I  Female
# 801    Overweight_Level_I  Female
# 802    Overweight_Level_I  Female
# 803    Overweight_Level_I    Male
# 804    Overweight_Level_I    Male
# 805    Overweight_Level_I    Male
# 806    Overweight_Level_I    Male
# 807    Overweight_Level_I    Male
# 808    Overweight_Level_I    Male
# 809    Overweight_Level_I  Female
# 810    Overweight_Level_I  Female
# 811    Overweight_Level_I    Male
# 812    Overweight_Level_I    Male
# 813    Overweight_Level_I  Female
# 814    Overweight_Level_I    Male
# 815    Overweight_Level_I    Male
# 816    Overweight_Level_I    Male
# 817    Overweight_Level_I    Male
# 818    Overweight_Level_I    Male
# 819    Overweight_Level_I    Male
# 820    Overweight_Level_I  Female
# 821    Overweight_Level_I  Female
# 822    Overweight_Level_I  Female
# 823    Overweight_Level_I  Female
# 824    Overweight_Level_I    Male
# 825    Overweight_Level_I  Female
# 826    Overweight_Level_I  Female
# 827    Overweight_Level_I  Female
# 828    Overweight_Level_I  Female
# 829    Overweight_Level_I  Female
# 830    Overweight_Level_I    Male
# 831    Overweight_Level_I    Male
# 832    Overweight_Level_I    Male
# 833    Overweight_Level_I    Male
# 834    Overweight_Level_I    Male
# 835    Overweight_Level_I  Female
# 836    Overweight_Level_I  Female
# 837    Overweight_Level_I    Male
# 838    Overweight_Level_I    Male
# 839    Overweight_Level_I    Male
# 840    Overweight_Level_I    Male
# 841    Overweight_Level_I    Male
# 842    Overweight_Level_I    Male
# 843    Overweight_Level_I    Male
# 844    Overweight_Level_I  Female
# 845    Overweight_Level_I  Female
# 846    Overweight_Level_I  Female
# 847    Overweight_Level_I  Female
# 848    Overweight_Level_I    Male
# 849    Overweight_Level_I    Male
# 850    Overweight_Level_I    Male
# 851    Overweight_Level_I  Female
# 852    Overweight_Level_I  Female
# 853    Overweight_Level_I  Female
# 854    Overweight_Level_I    Male
# 855    Overweight_Level_I    Male
# 856    Overweight_Level_I  Female
# 857    Overweight_Level_I    Male
# 858    Overweight_Level_I    Male
# 859    Overweight_Level_I    Male
# 860    Overweight_Level_I    Male
# 861    Overweight_Level_I  Female
# 862    Overweight_Level_I  Female
# 863    Overweight_Level_I  Female
# 864    Overweight_Level_I    Male
# 865    Overweight_Level_I  Female
# 866    Overweight_Level_I  Female
# 867    Overweight_Level_I  Female
# 868    Overweight_Level_I  Female
# 869    Overweight_Level_I  Female
# 870    Overweight_Level_I  Female
# 871    Overweight_Level_I    Male
# 872    Overweight_Level_I    Male
# 873    Overweight_Level_I  Female
# 874    Overweight_Level_I  Female
# 875    Overweight_Level_I  Female
# 876    Overweight_Level_I  Female
# 877    Overweight_Level_I  Female
# 878    Overweight_Level_I  Female
# 879    Overweight_Level_I  Female
# 880    Overweight_Level_I  Female
# 881    Overweight_Level_I  Female
# 882    Overweight_Level_I    Male
# 883    Overweight_Level_I  Female
# 884    Overweight_Level_I  Female
# 885    Overweight_Level_I  Female
# 886    Overweight_Level_I    Male
# 887    Overweight_Level_I    Male
# 888    Overweight_Level_I  Female
# 889    Overweight_Level_I  Female
# 890    Overweight_Level_I  Female
# 891    Overweight_Level_I  Female
# 892    Overweight_Level_I  Female
# 893    Overweight_Level_I    Male
# 894    Overweight_Level_I    Male
# 895    Overweight_Level_I    Male
# 896    Overweight_Level_I    Male
# 897    Overweight_Level_I    Male
# 898    Overweight_Level_I    Male
# 899    Overweight_Level_I    Male
# 900    Overweight_Level_I  Female
# 901    Overweight_Level_I    Male
# 902    Overweight_Level_I  Female
# 903    Overweight_Level_I  Female
# 904    Overweight_Level_I    Male
# 905    Overweight_Level_I    Male
# 906    Overweight_Level_I    Male
# 907    Overweight_Level_I  Female
# 908    Overweight_Level_I    Male
# 909    Overweight_Level_I    Male
# 910    Overweight_Level_I  Female
# 911    Overweight_Level_I  Female
# 912    Overweight_Level_I  Female
# 913    Overweight_Level_I    Male
# 914    Overweight_Level_I    Male
# 915    Overweight_Level_I  Female
# 916    Overweight_Level_I  Female
# 917    Overweight_Level_I  Female
# 918    Overweight_Level_I  Female
# 919    Overweight_Level_I  Female
# 920    Overweight_Level_I    Male
# 921    Overweight_Level_I    Male
# 922    Overweight_Level_I    Male
# 923    Overweight_Level_I    Male
# 924    Overweight_Level_I  Female
# 925    Overweight_Level_I  Female
# 926    Overweight_Level_I  Female
# 927    Overweight_Level_I    Male
# 928    Overweight_Level_I    Male
# 929    Overweight_Level_I    Male
# 930    Overweight_Level_I  Female
# 931    Overweight_Level_I  Female
# 932    Overweight_Level_I    Male
# 933    Overweight_Level_I    Male
# 934    Overweight_Level_I    Male
# 935    Overweight_Level_I  Female
# 936    Overweight_Level_I  Female
# 937    Overweight_Level_I  Female
# 938    Overweight_Level_I  Female
# 939    Overweight_Level_I    Male
# 940    Overweight_Level_I    Male
# 941    Overweight_Level_I    Male
# 942    Overweight_Level_I  Female
# 943    Overweight_Level_I    Male
# 944    Overweight_Level_I    Male
# 945    Overweight_Level_I    Male
# 946    Overweight_Level_I    Male
# 947    Overweight_Level_I  Female
# 948    Overweight_Level_I  Female
# 949    Overweight_Level_I    Male
# 950    Overweight_Level_I    Male
# 951    Overweight_Level_I  Female
# 952    Overweight_Level_I  Female
# 953    Overweight_Level_I  Female
# 954    Overweight_Level_I  Female
# 955    Overweight_Level_I  Female
# 956    Overweight_Level_I    Male
# 957    Overweight_Level_I  Female
# 958    Overweight_Level_I    Male
# 959    Overweight_Level_I  Female
# 960    Overweight_Level_I  Female
# 961    Overweight_Level_I    Male
# 962    Overweight_Level_I  Female
# 963    Overweight_Level_I  Female
# 964    Overweight_Level_I  Female
# 965    Overweight_Level_I  Female
# 966    Overweight_Level_I    Male
# 967    Overweight_Level_I  Female
# 968    Overweight_Level_I  Female
# 969    Overweight_Level_I    Male
# 970    Overweight_Level_I    Male
# 971    Overweight_Level_I    Male
# 972    Overweight_Level_I  Female
# 973    Overweight_Level_I  Female
# 974    Overweight_Level_I  Female
# 975    Overweight_Level_I  Female
# 976    Overweight_Level_I  Female
# 977   Overweight_Level_II    Male
# 978   Overweight_Level_II    Male
# 979   Overweight_Level_II    Male
# 980   Overweight_Level_II    Male
# 981   Overweight_Level_II    Male
# 982   Overweight_Level_II    Male
# 983   Overweight_Level_II    Male
# 984   Overweight_Level_II    Male
# 985   Overweight_Level_II    Male
# 986   Overweight_Level_II  Female
# 987   Overweight_Level_II    Male
# 988   Overweight_Level_II    Male
# 989   Overweight_Level_II  Female
# 990   Overweight_Level_II  Female
# 991   Overweight_Level_II    Male
# 992   Overweight_Level_II  Female
# 993   Overweight_Level_II  Female
# 994   Overweight_Level_II    Male
# 995   Overweight_Level_II    Male
# 996   Overweight_Level_II  Female
# 997   Overweight_Level_II  Female
# 998   Overweight_Level_II    Male
# 999   Overweight_Level_II    Male
# 1000  Overweight_Level_II  Female
# 1001  Overweight_Level_II    Male
# 1002  Overweight_Level_II    Male
# 1003  Overweight_Level_II  Female
# 1004  Overweight_Level_II    Male
# 1005  Overweight_Level_II  Female
# 1006  Overweight_Level_II    Male
# 1007  Overweight_Level_II    Male
# 1008  Overweight_Level_II    Male
# 1009  Overweight_Level_II    Male
# 1179  Overweight_Level_II    Male
# 1180  Overweight_Level_II    Male
# 1181  Overweight_Level_II    Male
# 1182  Overweight_Level_II    Male
# 1183  Overweight_Level_II  Female
# 1184  Overweight_Level_II    Male
# 1185  Overweight_Level_II    Male
# 1186  Overweight_Level_II    Male
# 1187  Overweight_Level_II    Male
# 1188  Overweight_Level_II  Female
# 1189  Overweight_Level_II  Female
# 1190  Overweight_Level_II    Male
# 1191  Overweight_Level_II    Male
# 1192  Overweight_Level_II    Male
# 1193  Overweight_Level_II    Male
# 1194  Overweight_Level_II    Male
# 1195  Overweight_Level_II    Male
# 1196  Overweight_Level_II    Male
# 1197  Overweight_Level_II    Male
# 1198  Overweight_Level_II    Male
# 1199  Overweight_Level_II    Male
# 1200  Overweight_Level_II    Male
# 1201  Overweight_Level_II    Male
# 1202  Overweight_Level_II    Male
# 1203  Overweight_Level_II  Female
# 1204  Overweight_Level_II  Female
# 1205  Overweight_Level_II  Female
# 1206  Overweight_Level_II    Male
# 1207  Overweight_Level_II    Male
# 1208  Overweight_Level_II  Female
# 1209       Obesity_Type_I    Male
# 1210       Obesity_Type_I    Male
# 1211       Obesity_Type_I    Male
# 1212       Obesity_Type_I    Male
# 1213       Obesity_Type_I  Female
# 1214       Obesity_Type_I  Female
# 1215       Obesity_Type_I  Female
# 1216       Obesity_Type_I  Female
# 1217       Obesity_Type_I  Female
# 1218       Obesity_Type_I  Female
# 1219       Obesity_Type_I    Male
# 1220       Obesity_Type_I    Male
# 1221       Obesity_Type_I  Female
# 1222       Obesity_Type_I  Female
# 1223       Obesity_Type_I  Female
# 1224       Obesity_Type_I    Male
# 1225       Obesity_Type_I    Male
# 1226       Obesity_Type_I  Female
# 1227       Obesity_Type_I  Female
# 1228       Obesity_Type_I    Male
# 1229       Obesity_Type_I  Female
# 1230       Obesity_Type_I    Male
# 1231       Obesity_Type_I  Female
# 1232       Obesity_Type_I    Male
# 1233       Obesity_Type_I    Male
# 1234       Obesity_Type_I    Male
# 1235       Obesity_Type_I    Male
# 1236       Obesity_Type_I    Male
# 1237       Obesity_Type_I    Male
# 1238       Obesity_Type_I  Female
# 1239       Obesity_Type_I  Female
# 1240       Obesity_Type_I  Female
# 1241       Obesity_Type_I  Female
# 1242       Obesity_Type_I  Female
# 1243       Obesity_Type_I    Male
# 1244       Obesity_Type_I  Female
# 1245       Obesity_Type_I    Male
# 1246       Obesity_Type_I    Male
# 1247       Obesity_Type_I  Female
# 1248       Obesity_Type_I    Male
# 1249       Obesity_Type_I    Male
# 1250       Obesity_Type_I  Female
# 1251       Obesity_Type_I  Female
# 1252       Obesity_Type_I    Male
# 1253       Obesity_Type_I    Male
# 1254       Obesity_Type_I    Male
# 1255       Obesity_Type_I    Male
# 1256       Obesity_Type_I    Male
# 1257       Obesity_Type_I    Male
# 1258       Obesity_Type_I  Female
# 1259       Obesity_Type_I  Female
# 1260       Obesity_Type_I    Male
# 1261       Obesity_Type_I    Male
# 1262       Obesity_Type_I    Male
# 2085     Obesity_Type_III  Female
# 2086     Obesity_Type_III  Female
# 2087     Obesity_Type_III  Female
# 2088     Obesity_Type_III  Female
# 2089     Obesity_Type_III  Female
# 2090     Obesity_Type_III  Female
# 2091     Obesity_Type_III  Female
# 2092     Obesity_Type_III  Female
# 2093     Obesity_Type_III  Female
# 2094     Obesity_Type_III  Female
# 2095     Obesity_Type_III  Female
# 2096     Obesity_Type_III  Female
# 2097     Obesity_Type_III  Female
# 2098     Obesity_Type_III  Female
# 2099     Obesity_Type_III  Female
# 2100     Obesity_Type_III  Female
# 2101     Obesity_Type_III  Female
# 2102     Obesity_Type_III  Female
# 2103     Obesity_Type_III  Female
# 2104     Obesity_Type_III  Female
# 2105     Obesity_Type_III  Female
# 2106     Obesity_Type_III  Female
# 2107     Obesity_Type_III  Female
# 2108     Obesity_Type_III  Female
# 2109     Obesity_Type_III  Female
# 2110     Obesity_Type_III  Female

# %%
# Memilih kolom 'Gender' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['NObeyesdad','Gender']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'jenis kelamin' sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'Gender', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Dari barplot di atas, dapat disimpulkan bahwa resiko obesitas akan cenderung meningkat kepada orang yang berjenis kelamin laki-laki dibandingkan dengan perempuan.

# %% [markdown]
# ### 5.2.b membandingkan kolom "Jenis Obesitas" dengan "Usia"

# %%
df["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Memilih kolom 'Age' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['NObeyesdad','Age']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'umur' sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'Age', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Dari bar diatas dapat dilihat bahwa kecenderungan usia yang semakin meningkat, akan semakin meningkatkan resiko obesitas pada level yang lebih tinggi.

# %% [markdown]
# ### 5.2.c membandingkan kolom "Jenis Obesitas" dengan "Tinggi"

# %%
df["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Memilih kolom 'Height' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['NObeyesdad','Height']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'tinggi' sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'Height', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Dari gambar diatas dapat diketahui bahwa sebaran jenis obesitas hampir tidak berpengaruh terhadap postur tinggi badan, hanya saja seseorang dengan tinggi 175 cm lebih rawan untuk terkena Obesitas Tipe II

# %% [markdown]
# ### 5.2.d membandingkan kolom "Jenis Obesitas" dengan "Berat badan"

# %%
df["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Memilih kolom 'Weight' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['NObeyesdad','Weight']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'berat badan' sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'Weight', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Dapat terlihat sangat jelas bahwa tingkat keparahan obesitas akan semakin meningkat seiring dengan peningkatan berat badan seseorang.

# %% [markdown]
# ### 5.2.e membandingkan kolom "Jenis Obesitas" dengan "Riwayat obesitas"

# %%
df["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Memilih kolom 'family_history_with_overweight' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['family_history_with_overweight','NObeyesdad']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'Riwayat obesitas' sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'family_history_with_overweight', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Dari chart di atas dapat terlihat bahwa sumbu y yang semakin menuju titik 0 menandakan bahwa tidak adanya riwayat keluarga yang memiliki diabetes. Hal itu menunjukan juga bahwa orang yang tidak memiliki riwayat obesitas keluarga, memiliki kecenderungan lebih tinggi terhadap berat badan normal ataupun berat badan kurang.

# %% [markdown]
# ### 5.2.f membandingkan kolom "Jenis Obesitas" dengan "Konsumsi Makan Kalori tinggi"

# %%
df["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Memilih kolom 'FAVC' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['NObeyesdad','FAVC']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'FAVC' sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'FAVC', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Berdasarkan gambar diatas juga dapat disimpulkan bahwa potensi tertinggi seseorang untuk terkena obesitas semakin meningkat apabila orang tersebut gemar mengkonsumsi makanan yang berkalori tinggi.

# %% [markdown]
# ### 5.2.g membandingkan kolom "Jenis Obesitas" dengan "Konsumsi buah-buahan"

# %%
df["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Memilih kolom 'FCVC' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['NObeyesdad','FCVC']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'FCVC' sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'FCVC', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Berdasarkan grafik dapat terlihat bahwa kemungkinan orang yang mengkonsumsi buah-buahan lebih banyak akan menurunkan resiko untuk mendapatkan obesitas, namun begitu ada sedikit anomali pada orang dengan obesitas tipe 3 yang justru meningkatkan peluang obesitas sedangkan konsumsi buah-buahan yang dilakukan berada pada angka yang cukup tinggi. Oleh karena itu perlu dilakukan pengecekan lebih lanjut untuk mendeteksi apakah ada outlier/data yang tidak valid.

# %% [markdown]
# ### 5.2.h membandingkan kolom "Jenis Obesitas" dengan "Jumlah makanan utama per hari"

# %%
df["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Memilih kolom 'NCP' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['NObeyesdad','NCP']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'NCP' sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'NCP', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Data diatas menunjukkan bahwa jumlah makan utama per hari meningkatkan resiko pada tingkat obesitas yang lebih tinggi yang berlaku pada orang yang berstatus obesitas, tidak berlaku bagi orang dengan berat badan normal maupun berat badan kurang.

# %% [markdown]
# ### 5.2.i membandingkan kolom "Jenis Obesitas" dengan "Frekuensi cemilan diantara makan utama"

# %%
df["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Memilih kolom 'CAEC' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['NObeyesdad','CAEC']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'CAEC' sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'CAEC', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Dari data diatas terlihat bahwa frekuensi cemilan diantara makan utama akan meningkatkan resiko obesitas pada tingkat yang lebih tinggi

# %% [markdown]
# ### 5.2.j membandingkan kolom "Jenis Obesitas" dengan "Konsumsi Rokok"

# %%
df["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Memilih kolom 'SMOKE' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['NObeyesdad','SMOKE']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'SMOKE' sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'SMOKE', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Berdasarkan grafik diatas nampak bahwa kejadian tertinggi untuk obesitas pada perokok adalah pada obesitas tipe 2 sedangkan untuk tingkat yang lain umumnya tidak terlalu berpengaruh.

# %% [markdown]
# ### 5.2.k membandingkan kolom "Jenis Obesitas" dengan "Konsumsi minum air per hari"

# %%
df["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Memilih kolom 'CH2O' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['NObeyesdad','CH2O']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'CH2O' sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'CH2O', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Frekuensi minum air pada penderita obesitas umumnya akan meningkatkan tingkat obesitas.

# %% [markdown]
# ### 5.2.l membandingkan kolom "Jenis Obesitas" dengan "Kontrol kalori harian"

# %%
df["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Memilih kolom 'SCC' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['NObeyesdad','SCC']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'SCC' sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'SCC', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# **Kesimpulan**

# %% [markdown]
# ### 5.2.m membandingkan kolom "Jenis Obesitas" dengan "Frekuensi aktifitas fisik"

# %%
df["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Memilih kolom 'FAF' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['NObeyesdad','FAF']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'FAF' sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'FAF', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# ### 5.2.n membandingkan kolom "Jenis Obesitas" dengan "Waktu yang dihabiskan untuk teknologi"

# %%
df["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Memilih kolom 'TUE' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['NObeyesdad','TUE']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'TUE'sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'TUE', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# ### 5.2.o membandingkan kolom "Jenis Obesitas" dengan "Frekuensi mengonsumsi alkohol"

# %%
df["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Memilih kolom 'CALC' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['NObeyesdad','CALC']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'CALC'sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'CALC', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# ### 5.2.p membandingkan kolom "Jenis Obesitas" dengan "Moda Utama yang digunakan dalam Transportasi"

# %%
df["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Memilih kolom 'MTRANS' dan 'Jenis Obesitas' dari DataFrame 'df'
df[['NObeyesdad','MTRANS']]

# Membuat grafik batang menggunakan seaborn catplot dengan menggunakan kolom 'Jenis Obesitas' sebagai sumbu x dan 'MTRANS'sebagai sumbu y
sns.catplot(data=df, x='NObeyesdad', y= 'MTRANS', hue='NObeyesdad', kind='bar')

# Mengatur label pada sumbu x
plt.xticks(rotation=90, ticks=(0,1,2,3,4,5,6), labels= np.array(df["NObeyesdad"].unique()))
plt.show()

# %% [markdown]
# ## 5.3. Barplot

# %%
# Memanggil barplot berdasarkan kolom tertentu
for col in df.columns:
    print(f'====== Grafik batang Jenis obesitas dengan {col} ======')
    ax = sns.barplot(data=df, x='NObeyesdad', y = col, hue='NObeyesdad')
    ax.bar_label(container=ax.containers[0], fontsize=10)
    plt.xticks(rotation = 90)
    plt.show()
    print("=====================================================")
# Out:
# ====== Grafik batang Jenis obesitas dengan Gender ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan Age ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan Height ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan Weight ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan family_history_with_overweight ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan FAVC ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan FCVC ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan NCP ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan CAEC ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan SMOKE ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan CH2O ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan SCC ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan FAF ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan TUE ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan CALC ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan MTRANS ======
# =====================================================
# ====== Grafik batang Jenis obesitas dengan NObeyesdad ======
# =====================================================

# %% [markdown]
# ## 5.4 Label Encoder

# %% [markdown]
# Label Encoder digunakan untuk melakukan kodifikasi terhadap variabel yang memiliki nilai kategorik menjadi nilai yang bersifat kuantitatif (non kategorik).

# %% [markdown]
# Sebelum kita mengubah variabel kedalam label encoder, kita perlu memisahkan data-data yang bersifat kategorik yang akan kita transform ke label encoder

# %%
df.head(5)
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female  21    1.62    64.0                yes               no    2.0  3.0
# 1  Female  21    1.52    56.0                yes               no    3.0  3.0
# 2    Male  23    1.80    77.0                yes               no    2.0  3.0
# 3    Male  27    1.80    87.0                 no               no    3.0  3.0
# 4    Male  22    1.78    89.8                 no               no    2.0  1.0
#
#      CAEC    SMOKE  CH2O SCC   FAF  TUE     CALC            MTRANS          \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#        NObeyesdad
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# 4  Overweight_Level_II

# %% [markdown]
# Dari dataset yang kita miliki terdapat beberapa variabel yang perlu dilakukan transformasi data ke label encoder diantaranya :
# - Gender
# - family_history_with_overweight
# - FAVC
# - CAEC
# - SMOKE
# - SCC
# - CALC
# - MTRANS
# - NObeyesdad

# %% [markdown]
# untuk membedakan hasil antara data yang telah dilakukan encoding dengan yang tidak maka kita perlu membuat 1 duplikat data dari data set awal df menjadi 'data label encoder' atau dle

# %%
dlc = df.copy()
dlc.head()
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female  21    1.62    64.0                yes               no    2.0  3.0
# 1  Female  21    1.52    56.0                yes               no    3.0  3.0
# 2    Male  23    1.80    77.0                yes               no    2.0  3.0
# 3    Male  27    1.80    87.0                 no               no    3.0  3.0
# 4    Male  22    1.78    89.8                 no               no    2.0  1.0
#
#      CAEC    SMOKE  CH2O SCC   FAF  TUE     CALC            MTRANS          \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#        NObeyesdad
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# 4  Overweight_Level_II

# %%
dlc["NObeyesdad"].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance
le = LabelEncoder()

# Fit the encoder to the labels
array = np.array(dle["NObeyesdad"].unique())
le.fit(array)

# Transform the labels to normalized encoding
encoded_labels = le.transform(dle["NObeyesdad"].unique())
print(encoded_labels) 

# Inverse transform to get the original labels
original_labels = le.inverse_transform(encoded_labels)
print(original_labels)
# Melihat hasil dari label encoder
labelkode = {'Kode': encoded_labels,
        'Kategori': original_labels}

label = pd.DataFrame(labelkode)
label.sort_values(by='Kode', ascending=True, inplace=True)
label
# Out:
# [1 5 6 2 0 3 4]
# ['Normal_Weight' 'Overweight_Level_I' 'Overweight_Level_II'
#  'Obesity_Type_I' 'Insufficient_Weight' 'Obesity_Type_II'
#  'Obesity_Type_III']
#    Kode       Kategori
# 4    0   Insufficient_Weight
# 0    1         Normal_Weight
# 3    2        Obesity_Type_I
# 5    3       Obesity_Type_II
# 6    4      Obesity_Type_III
# 1    5    Overweight_Level_I
# 2    6   Overweight_Level_II

# %% [markdown]
# ### 5.4.1. Label Encoder Variabel Jenis Obesitas/ 'NObeyesdad'

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance
le = LabelEncoder()

# Fit the encoder to the labels
array = np.array(dlc["NObeyesdad"].unique())
le.fit(array)

# Transform the labels to normalized encoding
encoded_labels = le.transform(dlc["NObeyesdad"].unique())
print(encoded_labels) 

# Inverse transform to get the original labels
original_labels = le.inverse_transform(encoded_labels)
print(original_labels)
# Melihat hasil dari label encoder
labelkode = {'Kode': encoded_labels,
        'Kategori': original_labels}

labelobes = pd.DataFrame(labelkode)
labelobes.sort_values(by='Kode', ascending=True, inplace=True)
labelobes

# Memaskukan Variabel Transformasi pada Dataset
dlc['En_Obes'] = le.fit_transform(dlc['NObeyesdad'])
dlc.head()
# Out:
# [1 5 6 2 0 3 4]
# ['Normal_Weight' 'Overweight_Level_I' 'Overweight_Level_II'
#  'Obesity_Type_I' 'Insufficient_Weight' 'Obesity_Type_II'
#  'Obesity_Type_III']
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female  21    1.62    64.0                yes               no    2.0  3.0
# 1  Female  21    1.52    56.0                yes               no    3.0  3.0
# 2    Male  23    1.80    77.0                yes               no    2.0  3.0
# 3    Male  27    1.80    87.0                 no               no    3.0  3.0
# 4    Male  22    1.78    89.8                 no               no    2.0  1.0
#
#      CAEC    SMOKE  CH2O SCC   FAF  TUE     CALC            MTRANS          \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#        NObeyesdad       En_Obes  En_Fam  En_FAVC  En_CAEC  En_SMOKE  En_SCC  \
# 0        Normal_Weight     1        1       0        2         0        0
# 1        Normal_Weight     1        1       0        2         1        1
# 2        Normal_Weight     1        1       0        2         0        0
# 3   Overweight_Level_I     5        0       0        2         0        0
# 4  Overweight_Level_II     6        0       0        2         0        0
#
#    En_CALC  En_MTRANS  En_Gender
# 0     3         3          0
# 1     2         3          0
# 2     1         3          1
# 3     1         4          1
# 4     2         3          1

# %% [markdown]
# ### 5.4.2. Label Encoder Variabel Riwayat Obesitas Keluarga/ 'family_history_with_overweight'

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance
le = LabelEncoder()

# Fit the encoder to the labels
array = np.array(dlc["family_history_with_overweight"].unique())
le.fit(array)

# Transform the labels to normalized encoding
encoded_labels = le.transform(dlc["family_history_with_overweight"].unique())
print(encoded_labels) 

# Inverse transform to get the original labels
original_labels = le.inverse_transform(encoded_labels)
print(original_labels)
# Melihat hasil dari label encoder
labelkode = {'Kode': encoded_labels,
        'Kategori': original_labels}

labelfamily = pd.DataFrame(labelkode)
labelfamily.sort_values(by='Kode', ascending=True, inplace=True)
labelfamily

# Memaskukan Variabel Transformasi pada Dataset
dlc['En_Fam'] = le.fit_transform(dlc['family_history_with_overweight'])
dlc.tail()
# Out:
# [1 0]
# ['yes' 'no']
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 2106  Female  21    1.71   131.41               yes               yes   3.0
# 2107  Female  22    1.75   133.74               yes               yes   3.0
# 2108  Female  23    1.75   133.69               yes               yes   3.0
# 2109  Female  24    1.74   133.35               yes               yes   3.0
# 2110  Female  24    1.74   133.47               yes               yes   3.0
#
#       NCP    CAEC    SMOKE  CH2O SCC   FAF   TUE     CALC     \
# 2106  3.0  Sometimes   no   1.73  no  1.68  0.906  Sometimes
# 2107  3.0  Sometimes   no   2.01  no  1.34  0.599  Sometimes
# 2108  3.0  Sometimes   no   2.05  no  1.41  0.646  Sometimes
# 2109  3.0  Sometimes   no   2.85  no  1.14  0.586  Sometimes
# 2110  3.0  Sometimes   no   2.86  no  1.03  0.714  Sometimes
#
#              MTRANS             NObeyesdad     En_Obes  En_Fam  En_FAVC  \
# 2106  Public_Transportation  Obesity_Type_III     4        1       1
# 2107  Public_Transportation  Obesity_Type_III     4        1       1
# 2108  Public_Transportation  Obesity_Type_III     4        1       1
# 2109  Public_Transportation  Obesity_Type_III     4        1       1
# 2110  Public_Transportation  Obesity_Type_III     4        1       1
#
#       En_CAEC  En_SMOKE  En_SCC  En_CALC  En_MTRANS  En_Gender
# 2106     2         0        0       2         3          0
# 2107     2         0        0       2         3          0
# 2108     2         0        0       2         3          0
# 2109     2         0        0       2         3          0
# 2110     2         0        0       2         3          0

# %% [markdown]
# ### 5.4.3. Label Encoder Variabel Konsumsi Makanan Tinggi Kalori/ 'FAVC'

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance
le = LabelEncoder()

# Fit the encoder to the labels
array = np.array(dlc["FAVC"].unique())
le.fit(array)

# Transform the labels to normalized encoding
encoded_labels = le.transform(dlc["FAVC"].unique())
print(encoded_labels) 

# Inverse transform to get the original labels
original_labels = le.inverse_transform(encoded_labels)
print(original_labels)
# Melihat hasil dari label encoder
labelkode = {'Kode': encoded_labels,
        'Kategori FAVC': original_labels}

labelFAVC = pd.DataFrame(labelkode)
labelFAVC.sort_values(by='Kode', ascending=True, inplace=True)
labelFAVC

# Memaskukan Variabel Transformasi pada Dataset
dlc['En_FAVC'] = le.fit_transform(dlc['FAVC'])
dlc.tail()
# Out:
# [0 1]
# ['no' 'yes']
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 2106  Female  21    1.71   131.41               yes               yes   3.0
# 2107  Female  22    1.75   133.74               yes               yes   3.0
# 2108  Female  23    1.75   133.69               yes               yes   3.0
# 2109  Female  24    1.74   133.35               yes               yes   3.0
# 2110  Female  24    1.74   133.47               yes               yes   3.0
#
#       NCP    CAEC    SMOKE  CH2O SCC   FAF   TUE     CALC     \
# 2106  3.0  Sometimes   no   1.73  no  1.68  0.906  Sometimes
# 2107  3.0  Sometimes   no   2.01  no  1.34  0.599  Sometimes
# 2108  3.0  Sometimes   no   2.05  no  1.41  0.646  Sometimes
# 2109  3.0  Sometimes   no   2.85  no  1.14  0.586  Sometimes
# 2110  3.0  Sometimes   no   2.86  no  1.03  0.714  Sometimes
#
#              MTRANS             NObeyesdad     En_Obes  En_Fam  En_FAVC  \
# 2106  Public_Transportation  Obesity_Type_III     4        1       1
# 2107  Public_Transportation  Obesity_Type_III     4        1       1
# 2108  Public_Transportation  Obesity_Type_III     4        1       1
# 2109  Public_Transportation  Obesity_Type_III     4        1       1
# 2110  Public_Transportation  Obesity_Type_III     4        1       1
#
#       En_CAEC  En_SMOKE  En_SCC  En_CALC  En_MTRANS  En_Gender
# 2106     2         0        0       2         3          0
# 2107     2         0        0       2         3          0
# 2108     2         0        0       2         3          0
# 2109     2         0        0       2         3          0
# 2110     2         0        0       2         3          0

# %% [markdown]
# ### 5.4.4. Label Encoder Variabel Konsumsi Cemilan diantara Waktu Makan/ 'CAEC'

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance
le = LabelEncoder()

# Fit the encoder to the labels
array = np.array(dlc["CAEC"].unique())
le.fit(array)

# Transform the labels to normalized encoding
encoded_labels = le.transform(dlc["CAEC"].unique())
print(encoded_labels) 

# Inverse transform to get the original labels
original_labels = le.inverse_transform(encoded_labels)
print(original_labels)
# Melihat hasil dari label encoder
labelkode = {'Kode': encoded_labels,
        'Kategori CAEC': original_labels}

labelCAEC = pd.DataFrame(labelkode)
labelCAEC.sort_values(by='Kode', ascending=True, inplace=True)
labelCAEC

# Memaskukan Variabel Transformasi pada Dataset
dlc['En_CAEC'] = le.fit_transform(dlc['CAEC'])
dlc.tail()
# Out:
# [2 1 0 3]
# ['Sometimes' 'Frequently' 'Always' 'no']
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 2106  Female  21    1.71   131.41               yes               yes   3.0
# 2107  Female  22    1.75   133.74               yes               yes   3.0
# 2108  Female  23    1.75   133.69               yes               yes   3.0
# 2109  Female  24    1.74   133.35               yes               yes   3.0
# 2110  Female  24    1.74   133.47               yes               yes   3.0
#
#       NCP    CAEC    SMOKE  CH2O SCC   FAF   TUE     CALC     \
# 2106  3.0  Sometimes   no   1.73  no  1.68  0.906  Sometimes
# 2107  3.0  Sometimes   no   2.01  no  1.34  0.599  Sometimes
# 2108  3.0  Sometimes   no   2.05  no  1.41  0.646  Sometimes
# 2109  3.0  Sometimes   no   2.85  no  1.14  0.586  Sometimes
# 2110  3.0  Sometimes   no   2.86  no  1.03  0.714  Sometimes
#
#              MTRANS             NObeyesdad     En_Obes  En_Fam  En_FAVC  \
# 2106  Public_Transportation  Obesity_Type_III     4        1       1
# 2107  Public_Transportation  Obesity_Type_III     4        1       1
# 2108  Public_Transportation  Obesity_Type_III     4        1       1
# 2109  Public_Transportation  Obesity_Type_III     4        1       1
# 2110  Public_Transportation  Obesity_Type_III     4        1       1
#
#       En_CAEC  En_SMOKE  En_SCC  En_CALC  En_MTRANS  En_Gender
# 2106     2         0        0       2         3          0
# 2107     2         0        0       2         3          0
# 2108     2         0        0       2         3          0
# 2109     2         0        0       2         3          0
# 2110     2         0        0       2         3          0

# %% [markdown]
# ### 5.4.5. Label Encoder Variabel Apakah mengkonsumsi rokok/ 'SMOKE'

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance
le = LabelEncoder()

# Fit the encoder to the labels
array = np.array(dlc["SMOKE"].unique())
le.fit(array)

# Transform the labels to normalized encoding
encoded_labels = le.transform(dlc["SMOKE"].unique())
print(encoded_labels) 

# Inverse transform to get the original labels
original_labels = le.inverse_transform(encoded_labels)
print(original_labels)
# Melihat hasil dari label encoder
labelkode = {'Kode': encoded_labels,
        'Kategori SMOKE': original_labels}

labelSMOKE = pd.DataFrame(labelkode)
labelSMOKE.sort_values(by='Kode', ascending=True, inplace=True)
labelSMOKE

# Memaskukan Variabel Transformasi pada Dataset
dlc['En_SMOKE'] = le.fit_transform(dlc['SMOKE'])
dlc.tail()
# Out:
# [0 1]
# ['no' 'yes']
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 2106  Female  21    1.71   131.41               yes               yes   3.0
# 2107  Female  22    1.75   133.74               yes               yes   3.0
# 2108  Female  23    1.75   133.69               yes               yes   3.0
# 2109  Female  24    1.74   133.35               yes               yes   3.0
# 2110  Female  24    1.74   133.47               yes               yes   3.0
#
#       NCP    CAEC    SMOKE  CH2O SCC   FAF   TUE     CALC     \
# 2106  3.0  Sometimes   no   1.73  no  1.68  0.906  Sometimes
# 2107  3.0  Sometimes   no   2.01  no  1.34  0.599  Sometimes
# 2108  3.0  Sometimes   no   2.05  no  1.41  0.646  Sometimes
# 2109  3.0  Sometimes   no   2.85  no  1.14  0.586  Sometimes
# 2110  3.0  Sometimes   no   2.86  no  1.03  0.714  Sometimes
#
#              MTRANS             NObeyesdad     En_Obes  En_Fam  En_FAVC  \
# 2106  Public_Transportation  Obesity_Type_III     4        1       1
# 2107  Public_Transportation  Obesity_Type_III     4        1       1
# 2108  Public_Transportation  Obesity_Type_III     4        1       1
# 2109  Public_Transportation  Obesity_Type_III     4        1       1
# 2110  Public_Transportation  Obesity_Type_III     4        1       1
#
#       En_CAEC  En_SMOKE  En_SCC  En_CALC  En_MTRANS  En_Gender
# 2106     2         0        0       2         3          0
# 2107     2         0        0       2         3          0
# 2108     2         0        0       2         3          0
# 2109     2         0        0       2         3          0
# 2110     2         0        0       2         3          0

# %% [markdown]
# ### 5.4.6. Label Encoder Variabel Apakah melakukan kontrol konsumsi kalori harian / 'SCC'

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance
le = LabelEncoder()

# Fit the encoder to the labels
array = np.array(dlc["SCC"].unique())
le.fit(array)

# Transform the labels to normalized encoding
encoded_labels = le.transform(dlc["SCC"].unique())
print(encoded_labels) 

# Inverse transform to get the original labels
original_labels = le.inverse_transform(encoded_labels)
print(original_labels)
# Melihat hasil dari label encoder
labelkode = {'Kode': encoded_labels,
        'Kategori SCC': original_labels}

labelSCC = pd.DataFrame(labelkode)
labelSCC.sort_values(by='Kode', ascending=True, inplace=True)
labelSCC

# Memaskukan Variabel Transformasi pada Dataset
dlc['En_SCC'] = le.fit_transform(dlc['SCC'])
dlc.tail()
# Out:
# [0 1]
# ['no' 'yes']
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 2106  Female  21    1.71   131.41               yes               yes   3.0
# 2107  Female  22    1.75   133.74               yes               yes   3.0
# 2108  Female  23    1.75   133.69               yes               yes   3.0
# 2109  Female  24    1.74   133.35               yes               yes   3.0
# 2110  Female  24    1.74   133.47               yes               yes   3.0
#
#       NCP    CAEC    SMOKE  CH2O SCC   FAF   TUE     CALC     \
# 2106  3.0  Sometimes   no   1.73  no  1.68  0.906  Sometimes
# 2107  3.0  Sometimes   no   2.01  no  1.34  0.599  Sometimes
# 2108  3.0  Sometimes   no   2.05  no  1.41  0.646  Sometimes
# 2109  3.0  Sometimes   no   2.85  no  1.14  0.586  Sometimes
# 2110  3.0  Sometimes   no   2.86  no  1.03  0.714  Sometimes
#
#              MTRANS             NObeyesdad     En_Obes  En_Fam  En_FAVC  \
# 2106  Public_Transportation  Obesity_Type_III     4        1       1
# 2107  Public_Transportation  Obesity_Type_III     4        1       1
# 2108  Public_Transportation  Obesity_Type_III     4        1       1
# 2109  Public_Transportation  Obesity_Type_III     4        1       1
# 2110  Public_Transportation  Obesity_Type_III     4        1       1
#
#       En_CAEC  En_SMOKE  En_SCC  En_CALC  En_MTRANS  En_Gender
# 2106     2         0        0       2         3          0
# 2107     2         0        0       2         3          0
# 2108     2         0        0       2         3          0
# 2109     2         0        0       2         3          0
# 2110     2         0        0       2         3          0

# %% [markdown]
# ### 5.4.7. Label Encoder Variabel Pola Konsumsi Alkohol / 'CALC'

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance
le = LabelEncoder()

# Fit the encoder to the labels
array = np.array(dlc["CALC"].unique())
le.fit(array)

# Transform the labels to normalized encoding
encoded_labels = le.transform(dlc["CALC"].unique())
print(encoded_labels) 

# Inverse transform to get the original labels
original_labels = le.inverse_transform(encoded_labels)
print(original_labels)
# Melihat hasil dari label encoder
labelkode = {'Kode': encoded_labels,
        'Kategori CALC': original_labels}

labelCALC = pd.DataFrame(labelkode)
labelCALC.sort_values(by='Kode', ascending=True, inplace=True)
labelCALC

# Memaskukan Variabel Transformasi pada Dataset
dlc['En_CALC'] = le.fit_transform(dlc['CALC'])
dlc.tail()
# Out:
# [3 2 1 0]
# ['no' 'Sometimes' 'Frequently' 'Always']
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 2106  Female  21    1.71   131.41               yes               yes   3.0
# 2107  Female  22    1.75   133.74               yes               yes   3.0
# 2108  Female  23    1.75   133.69               yes               yes   3.0
# 2109  Female  24    1.74   133.35               yes               yes   3.0
# 2110  Female  24    1.74   133.47               yes               yes   3.0
#
#       NCP    CAEC    SMOKE  CH2O SCC   FAF   TUE     CALC     \
# 2106  3.0  Sometimes   no   1.73  no  1.68  0.906  Sometimes
# 2107  3.0  Sometimes   no   2.01  no  1.34  0.599  Sometimes
# 2108  3.0  Sometimes   no   2.05  no  1.41  0.646  Sometimes
# 2109  3.0  Sometimes   no   2.85  no  1.14  0.586  Sometimes
# 2110  3.0  Sometimes   no   2.86  no  1.03  0.714  Sometimes
#
#              MTRANS             NObeyesdad     En_Obes  En_Fam  En_FAVC  \
# 2106  Public_Transportation  Obesity_Type_III     4        1       1
# 2107  Public_Transportation  Obesity_Type_III     4        1       1
# 2108  Public_Transportation  Obesity_Type_III     4        1       1
# 2109  Public_Transportation  Obesity_Type_III     4        1       1
# 2110  Public_Transportation  Obesity_Type_III     4        1       1
#
#       En_CAEC  En_SMOKE  En_SCC  En_CALC  En_MTRANS  En_Gender
# 2106     2         0        0       2         3          0
# 2107     2         0        0       2         3          0
# 2108     2         0        0       2         3          0
# 2109     2         0        0       2         3          0
# 2110     2         0        0       2         3          0

# %% [markdown]
# ### 5.4.8. Label Encoder Variabel Pola Transportasi Harian / 'MTRANS'

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance
le = LabelEncoder()

# Fit the encoder to the labels
array = np.array(dlc["MTRANS"].unique())
le.fit(array)

# Transform the labels to normalized encoding
encoded_labels = le.transform(dlc["MTRANS"].unique())
print(encoded_labels) 

# Inverse transform to get the original labels
original_labels = le.inverse_transform(encoded_labels)
print(original_labels)
# Melihat hasil dari label encoder
labelkode = {'Kode': encoded_labels,
        'Kategori MTRANS': original_labels}

labelMTRANS = pd.DataFrame(labelkode)
labelMTRANS.sort_values(by='Kode', ascending=True, inplace=True)
labelMTRANS

# Memaskukan Variabel Transformasi pada Dataset
dlc['En_MTRANS'] = le.fit_transform(dlc['MTRANS'])
dlc.tail()
# Out:
# [3 4 0 2 1]
# ['Public_Transportation' 'Walking' 'Automobile' 'Motorbike' 'Bike']
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 2106  Female  21    1.71   131.41               yes               yes   3.0
# 2107  Female  22    1.75   133.74               yes               yes   3.0
# 2108  Female  23    1.75   133.69               yes               yes   3.0
# 2109  Female  24    1.74   133.35               yes               yes   3.0
# 2110  Female  24    1.74   133.47               yes               yes   3.0
#
#       NCP    CAEC    SMOKE  CH2O SCC   FAF   TUE     CALC     \
# 2106  3.0  Sometimes   no   1.73  no  1.68  0.906  Sometimes
# 2107  3.0  Sometimes   no   2.01  no  1.34  0.599  Sometimes
# 2108  3.0  Sometimes   no   2.05  no  1.41  0.646  Sometimes
# 2109  3.0  Sometimes   no   2.85  no  1.14  0.586  Sometimes
# 2110  3.0  Sometimes   no   2.86  no  1.03  0.714  Sometimes
#
#              MTRANS             NObeyesdad     En_Obes  En_Fam  En_FAVC  \
# 2106  Public_Transportation  Obesity_Type_III     4        1       1
# 2107  Public_Transportation  Obesity_Type_III     4        1       1
# 2108  Public_Transportation  Obesity_Type_III     4        1       1
# 2109  Public_Transportation  Obesity_Type_III     4        1       1
# 2110  Public_Transportation  Obesity_Type_III     4        1       1
#
#       En_CAEC  En_SMOKE  En_SCC  En_CALC  En_MTRANS  En_Gender
# 2106     2         0        0       2         3          0
# 2107     2         0        0       2         3          0
# 2108     2         0        0       2         3          0
# 2109     2         0        0       2         3          0
# 2110     2         0        0       2         3          0

# %% [markdown]
# ### 5.4.9. Label Encoder Variabel Jenis Kelamin / 'Gender'

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance
le = LabelEncoder()

# Fit the encoder to the labels
array = np.array(dlc["Gender"].unique())
le.fit(array)

# Transform the labels to normalized encoding
encoded_labels = le.transform(dlc["Gender"].unique())
print(encoded_labels) 

# Inverse transform to get the original labels
original_labels = le.inverse_transform(encoded_labels)
print(original_labels)
# Melihat hasil dari label encoder
labelkode = {'Kode': encoded_labels,
        'Kategori Gender': original_labels}

labelGender = pd.DataFrame(labelkode)
labelGender.sort_values(by='Kode', ascending=True, inplace=True)
labelGender

# Memaskukan Variabel Transformasi pada Dataset
dlc['En_Gender'] = le.fit_transform(dlc['Gender'])
dlc.tail()
# Out:
# [0 1]
# ['Female' 'Male']
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 2106  Female  21    1.71   131.41               yes               yes   3.0
# 2107  Female  22    1.75   133.74               yes               yes   3.0
# 2108  Female  23    1.75   133.69               yes               yes   3.0
# 2109  Female  24    1.74   133.35               yes               yes   3.0
# 2110  Female  24    1.74   133.47               yes               yes   3.0
#
#       NCP    CAEC    SMOKE  CH2O SCC   FAF   TUE     CALC     \
# 2106  3.0  Sometimes   no   1.73  no  1.68  0.906  Sometimes
# 2107  3.0  Sometimes   no   2.01  no  1.34  0.599  Sometimes
# 2108  3.0  Sometimes   no   2.05  no  1.41  0.646  Sometimes
# 2109  3.0  Sometimes   no   2.85  no  1.14  0.586  Sometimes
# 2110  3.0  Sometimes   no   2.86  no  1.03  0.714  Sometimes
#
#              MTRANS             NObeyesdad     En_Obes  En_Fam  En_FAVC  \
# 2106  Public_Transportation  Obesity_Type_III     4        1       1
# 2107  Public_Transportation  Obesity_Type_III     4        1       1
# 2108  Public_Transportation  Obesity_Type_III     4        1       1
# 2109  Public_Transportation  Obesity_Type_III     4        1       1
# 2110  Public_Transportation  Obesity_Type_III     4        1       1
#
#       En_CAEC  En_SMOKE  En_SCC  En_CALC  En_MTRANS  En_Gender
# 2106     2         0        0       2         3          0
# 2107     2         0        0       2         3          0
# 2108     2         0        0       2         3          0
# 2109     2         0        0       2         3          0
# 2110     2         0        0       2         3          0

# %% [markdown]
# Dari hasil Encoding beberapa variabel diatas, untuk melihat perbedaan antara Data frame yang belum ter encoding dengan Data frame yang telah ditransformasi encoding maka perlu dibuat satu dataframe baru tanpa memuat variabel :
# - Gender
# - family_history_with_overweight
# - FAVC
# - CAEC
# - SMOKE
# - SCC
# - CALC
# - MTRANS
# - NObeyesdad

# %%
# Dropping specific columns
# 'dlc' is your original DataFrame
dfe = dlc.drop(['Gender', 'family_history_with_overweight', 'FAVC', 
                'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS', 'NObeyesdad'], axis=1)

# Display the new DataFrame
dfe.head()
# Out:
#    Age  Height  Weight  FCVC  NCP  CH2O  FAF  TUE  En_Obes  En_Fam  En_FAVC  \
# 0  21    1.62    64.0    2.0  3.0   2.0  0.0  1.0     1        1       0
# 1  21    1.52    56.0    3.0  3.0   3.0  3.0  0.0     1        1       0
# 2  23    1.80    77.0    2.0  3.0   2.0  2.0  1.0     1        1       0
# 3  27    1.80    87.0    3.0  3.0   2.0  2.0  0.0     5        0       0
# 4  22    1.78    89.8    2.0  1.0   2.0  0.0  0.0     6        0       0
#
#    En_CAEC  En_SMOKE  En_SCC  En_CALC  En_MTRANS  En_Gender
# 0     2         0        0       3         3          0
# 1     2         1        1       2         3          0
# 2     2         0        0       1         3          1
# 3     2         0        0       1         4          1
# 4     2         0        0       2         3          1

# %% [markdown]
# ## 5.5 Korelasi Pearson

# %% [markdown]
# Pada langkah ini dilakukan pendeteksian seberapa kuat hubungan antara 2 variabel yang terdapat pada data set obesitas dengan rentang nilai -1 hingga 1 tetapi korelasi Pearson tidak memberikan informasi tentang penyebab dan akibat.
#
# - Jika mendekati 1 maka menunjukkan hubungan linear positif antara 2 variabel
# - Jika mendekati -1 maka menunjukkan hubungan linear negatif antara 2 variabel
# - Jika mendekati 0 maka tidak ada hubungan

# %%
# Menghitung korelasi antar kolom pada DataFrame 'df' menggunakan metode korelasi Pearson
pearson_corr = dfe.corr(method='pearson')

# Menampilkan nilai korelasi antar kolom dalam bentuk tabel
pearson_corr
# Out:
#               Age     Height    Weight     FCVC       NCP      CH2O    \
# Age        1.000000 -0.025775  0.203451  0.017020 -0.043951 -0.045583
# Height    -0.025775  1.000000  0.462264 -0.038580  0.243387  0.213469
# Weight     0.203451  0.462264  1.000000  0.216268  0.107413  0.200543
# FCVC       0.017020 -0.038580  0.216268  1.000000  0.042045  0.068401
# NCP       -0.043951  0.243387  0.107413  0.042045  1.000000  0.056936
# CH2O      -0.045583  0.213469  0.200543  0.068401  0.056936  1.000000
# FAF       -0.145081  0.295354 -0.051355  0.019936  0.129519  0.167181
# TUE       -0.296609  0.051583 -0.071571 -0.101221  0.036404  0.011924
# En_Obes    0.235660  0.039671  0.387641  0.018597 -0.092637  0.108839
# En_Fam     0.205494  0.247245  0.496819  0.040395  0.071273  0.147376
# En_FAVC    0.063392  0.177721  0.272303 -0.027227 -0.006969  0.009733
# En_CAEC    0.084146  0.048763  0.287492 -0.054612 -0.097788  0.145025
# En_SMOKE   0.091354  0.055725  0.025747  0.014376  0.007806 -0.032003
# En_SCC    -0.116028 -0.133369 -0.201906  0.071835 -0.015615  0.008040
# En_CALC   -0.045578 -0.129569 -0.206676 -0.060802 -0.071787 -0.091384
# En_MTRANS -0.600567 -0.073756  0.004610  0.064703 -0.053868  0.043968
# En_Gender  0.048682  0.618145  0.161665 -0.274425  0.067556  0.107889
#
#               FAF       TUE     En_Obes   En_Fam    En_FAVC   En_CAEC  \
# Age       -0.145081 -0.296609  0.235660  0.205494  0.063392  0.084146
# Height     0.295354  0.051583  0.039671  0.247245  0.177721  0.048763
# Weight    -0.051355 -0.071571  0.387641  0.496819  0.272303  0.287492
# FCVC       0.019936 -0.101221  0.018597  0.040395 -0.027227 -0.054612
# NCP        0.129519  0.036404 -0.092637  0.071273 -0.006969 -0.097788
# CH2O       0.167181  0.011924  0.108839  0.147376  0.009733  0.145025
# FAF        1.000000  0.058586 -0.129504 -0.056647 -0.107936 -0.030070
# TUE        0.058586  1.000000 -0.069446  0.022941  0.068410 -0.048565
# En_Obes   -0.129504 -0.069446  1.000000  0.313667  0.044582  0.327295
# En_Fam    -0.056647  0.022941  0.313667  1.000000  0.208036  0.169787
# En_FAVC   -0.107936  0.068410  0.044582  0.208036  1.000000  0.150068
# En_CAEC   -0.030070 -0.048565  0.327295  0.169787  0.150068  1.000000
# En_SMOKE   0.011215  0.017610 -0.023256  0.017385 -0.050660 -0.055282
# En_SCC     0.074273 -0.010927 -0.050679 -0.185422 -0.190658 -0.109179
# En_CALC    0.086783  0.045866 -0.134632  0.036676 -0.089520 -0.047540
# En_MTRANS  0.006351  0.176949 -0.046202 -0.101540 -0.069800 -0.048535
# En_Gender  0.189590  0.017290  0.024908  0.102512  0.064934  0.091543
#
#            En_SMOKE   En_SCC    En_CALC  En_MTRANS  En_Gender
# Age        0.091354 -0.116028 -0.045578 -0.600567   0.048682
# Height     0.055725 -0.133369 -0.129569 -0.073756   0.618145
# Weight     0.025747 -0.201906 -0.206676  0.004610   0.161665
# FCVC       0.014376  0.071835 -0.060802  0.064703  -0.274425
# NCP        0.007806 -0.015615 -0.071787 -0.053868   0.067556
# CH2O      -0.032003  0.008040 -0.091384  0.043968   0.107889
# FAF        0.011215  0.074273  0.086783  0.006351   0.189590
# TUE        0.017610 -0.010927  0.045866  0.176949   0.017290
# En_Obes   -0.023256 -0.050679 -0.134632 -0.046202   0.024908
# En_Fam     0.017385 -0.185422  0.036676 -0.101540   0.102512
# En_FAVC   -0.050660 -0.190658 -0.089520 -0.069800   0.064934
# En_CAEC   -0.055282 -0.109179 -0.047540 -0.048535   0.091543
# En_SMOKE   1.000000  0.047731 -0.082471 -0.010702   0.044698
# En_SCC     0.047731  1.000000 -0.003463  0.043157  -0.102633
# En_CALC   -0.082471 -0.003463  1.000000 -0.012452   0.007616
# En_MTRANS -0.010702  0.043157 -0.012452  1.000000  -0.137537
# En_Gender  0.044698 -0.102633  0.007616 -0.137537   1.000000

# %%
# Menghitung matriks korelasi antar kolom pada DataFrame 'df'
matrikscorr = dfe.corr()

# Membuat gambar plot dengan ukuran (figsize) 15x8
plt.figure(figsize=(15, 8))

# Membuat heatmap menggunakan seaborn untuk memvisualisasikan matriks korelasi
# Parameter 'cmap' mengatur skema warna heatmap menjadi 'Reds'
# Parameter 'annot=True' mengaktifkan penulisan nilai korelasi di dalam sel
# Parameter 'annot_kws={'fontsize':12}' mengatur ukuran font untuk nilai korelasi menjadi 12
sns.heatmap(matriksCorr, cmap='Reds', annot=True, annot_kws={'fontsize': 12})

# Menampilkan gambar plot
plt.show()

# %% [markdown]
# # 6. Preprocessing Data

# %% [markdown]
# Pada tahapan ini akan dilakukan beberapa perapihan data yang sekiranya perlu untuk dilakukan, seperti pengecekan outlier, penghapusan outlier, pengisian data missing value dan tindakan lainnya bila diperlukan.

# %% [markdown]
# ## 6.1. Deteksi dan menangani Outlier

# %%
# Melakukan copy data
dfe_1 = dfe.copy()

# Melihat susunan kolom dataset
dfe_1.columns.values
# Out:
# array(['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE',
#        'En_Obes', 'En_Fam', 'En_FAVC', 'En_CAEC', 'En_SMOKE', 'En_SCC',
#        'En_CALC', 'En_MTRANS', 'En_Gender'], dtype=object)

# %%
# Melakukan pengecekan Outlier
kolom = np.array(dfe_1.columns.values)
print(kolom)

# Membuat iterasi pengecekan outlier dengan boxplot

for col in dfe_1.columns:
    plt.boxplot(dfe_1[col],vert=True)
    plt.title(col)
    plt.show()
# Out:
# ['Age' 'Height' 'Weight' 'FCVC' 'NCP' 'CH2O' 'FAF' 'TUE' 'En_Obes'
#  'En_Fam' 'En_FAVC' 'En_CAEC' 'En_SMOKE' 'En_SCC' 'En_CALC' 'En_MTRANS'
#  'En_Gender']

# %% [markdown]
# pada output pendeteksi outlier dari kolom dengan data yang bersifat numerical di atas dapat dilihat bahwa kolom:
# + Age
# + NCP
# memiliki outlier yang banyak. Sehingga, harus dibersihkan outlier pada data

# %%
df_outlier = dfe_1.copy()
kolom1 = np.array(df_outlier.columns.values)
print(kolom1)
# Out:
# ['Age' 'Height' 'Weight' 'FCVC' 'NCP' 'CH2O' 'FAF' 'TUE' 'En_Obes'
#  'En_Fam' 'En_FAVC' 'En_CAEC' 'En_SMOKE' 'En_SCC' 'En_CALC' 'En_MTRANS'
#  'En_Gender']

# %%
def remove_outliers(df_outlier):
    for col in df_outlier[kolom]:
        Q1 = df_outlier[col].quantile(0.25)
        Q3 = df_outlier[col].quantile(0.75)
        IQR = Q3 - Q1
        upper_bound = Q3 + 1.5 * IQR
        lower_bound = Q1 - 1.5 * IQR
        df_outlier = df_outlier[(df_outlier[col] > lower_bound) & (df_outlier[col] < upper_bound)]
    return df_outlier

df_outlier = remove_outliers(df_outlier)

# %%
df_outlier.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        0 non-null      int64
#  1   Height     0 non-null      float64
#  2   Weight     0 non-null      float64
#  3   FCVC       0 non-null      float64
#  4   NCP        0 non-null      float64
#  5   CH2O       0 non-null      float64
#  6   FAF        0 non-null      float64
#  7   TUE        0 non-null      float64
#  8   En_Obes    0 non-null      int32
#  9   En_Fam     0 non-null      int32
#  10  En_FAVC    0 non-null      int32
#  11  En_CAEC    0 non-null      int32
#  12  En_SMOKE   0 non-null      int32
#  13  En_SCC     0 non-null      int32
#  14  En_CALC    0 non-null      int32
#  15  En_MTRANS  0 non-null      int32
#  16  En_Gender  0 non-null      int32
# dtypes: float64(7), int32(9), int64(1)
# memory usage: 0.0 bytes

# %%
for col in dfclean.columns:
    plt.boxplot(dfclean[col],vert=True)
    plt.title(col)
    plt.show()
