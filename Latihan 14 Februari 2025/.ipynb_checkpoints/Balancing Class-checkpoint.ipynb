# %% [markdown]
# # 1. DATA LOADING

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Healthcare-Diabetes.csv")

# %% [markdown]
# df

# %% [markdown]
# # 2. DATA CLEANSING

# %%
df.isnull().sum()
# Out:
# Id                          0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # 3. PREPROCESSING DATA

# %%
df_new = df.copy()
df_new = df_new[["Pregnancies","Glucose","BloodPressure","SkinThickness","Insulin","BMI","DiabetesPedigreeFunction","Age","Outcome"]]
df_new
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               6      148             72             35        0  33.6
# 1               1       85             66             29        0  26.6
# 2               8      183             64              0        0  23.3
# 3               1       89             66             23       94  28.1
# 4               0      137             40             35      168  43.1
# ...           ...      ...            ...            ...      ...   ...
# 2763            2       75             64             24       55  29.7
# 2764            8      179             72             42      130  32.7
# 2765            6       85             78              0        0  31.2
# 2766            0      129            110             46      130  67.1
# 2767            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.627   50        1
# ...

# %%
df_new2 = df.copy()
df_new2
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        1            6      148             72             35        0  33.6
# 1        2            1       85             66             29        0  26.6
# 2        3            8      183             64              0        0  23.3
# 3        4            1       89             66             23       94  28.1
# 4        5            0      137             40             35      168  43.1
# ...    ...          ...      ...            ...            ...      ...   ...
# 2763  2764            2       75             64             24       55  29.7
# 2764  2765            8      179             72             42      130  32.7
# 2765  2766            6       85             78              0        0  31.2
# 2766  2767            0      129            110             46      130  67.1
# 2767  2768            2       81             72             15       76  30.1
#
# ...

# %%
df_new2.drop(columns=["Id"],inplace = True)

# %%
df_new2
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               6      148             72             35        0  33.6
# 1               1       85             66             29        0  26.6
# 2               8      183             64              0        0  23.3
# 3               1       89             66             23       94  28.1
# 4               0      137             40             35      168  43.1
# ...           ...      ...            ...            ...      ...   ...
# 2763            2       75             64             24       55  29.7
# 2764            8      179             72             42      130  32.7
# 2765            6       85             78              0        0  31.2
# 2766            0      129            110             46      130  67.1
# 2767            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.627   50        1
# ...

# %% [markdown]
# # 4. Balancing

# %% [markdown]
# ## 4.1 Balancing(OVERSAMPLING)

# %%
#masih data asli (bukan data latih)
x = df_new2.drop(columns=["Outcome"])
y = df_new2["Outcome"]

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from collections import Counter
#memanggil SMOTE
smote = SMOTE(random_state=42)

# %%
#kode oversampling

#Split data menjadi Train (80%) dan Test (20%)*
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# *Oversampling dengan SMOTE (hanya pada training data)*
smote = SMOTE(random_state=42)
x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)
print("Distribusi kelas setelah SMOTE (Oversampling):", Counter(y_train_smote))
# Out:
# Distribusi kelas setelah SMOTE (Oversampling): Counter({0: 1453, 1: 1453})

# %%
#kode oversampling

#Split data menjadi Train (70%) dan Test (30%)*
x_train70, x_test30, y_train70, y_test30 = train_test_split(x, y, test_size=0.3, random_state=42, stratify=y)

# *Oversampling dengan SMOTE (hanya pada training data)*
smote = SMOTE(random_state=42)
x_train_smote7030, y_train_smote7030 = smote.fit_resample(x_train70, y_train70)
print("Distribusi kelas setelah SMOTE (Oversampling):", Counter(y_train_smote7030))
# Out:
# Distribusi kelas setelah SMOTE (Oversampling): Counter({0: 1271, 1: 1271})

# %% [markdown]
# ## Balancing (OVERSAMPLING) 80: 20

# %% [markdown]
# ## 4.2 Balancing(UNDERSAMPLING)

# %%
#masih data asli (bukan data latih)
x = df_new2.drop(columns=["Outcome"])
y = df_new2["Outcome"]

# %%
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split
from collections import Counter
#memanggil SMOTE
smote = SMOTE(random_state=42)

# %%
#kode oversampling

#Split data menjadi Train (80%) dan Test (20%)*
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# *Oversampling dengan SMOTE (hanya pada training data)*
rus = RandomUnderSampler(random_state=42)
x_train_rus, y_train_rus = rus.fit_resample(x_train, y_train)
print("Distribusi kelas setelah Random Under Sample (Underrsampling):", Counter(y_train_rus))
# Out:
# Distribusi kelas setelah Random Under Sample (Underrsampling): Counter({0: 761, 1: 761})

# %%
#kode oversampling

#Split data menjadi Train (70%) dan Test (30%)*
x_train70, x_test30, y_train70, y_test30 = train_test_split(x, y, test_size=0.3, random_state=42, stratify=y)

# *Oversampling dengan SMOTE (hanya pada training data)*
rus = RandomUnderSampler(random_state=42)
x_train_rus7030, y_train_rus7030 = rus.fit_resample(x_train70, y_train70)
print("Distribusi kelas setelah Random Under Sample (Underrsampling):", Counter(y_train_rus7030))
# Out:
# Distribusi kelas setelah Random Under Sample (Underrsampling): Counter({0: 666, 1: 666})

# %%
y_train_rus7030
# Out:
# 929     0
# 793     0
# 2024    0
# 859     0
# 895     0
#        ..
# 2026    1
# 1914    1
# 1844    1
# 1956    1
# 1595    1
# Name: Outcome, Length: 1332, dtype: int64

# %% [markdown]
# # 5. Training Testing ML

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %% [markdown]
# ### 5.1 Buat Training KNN

# %%
# memuat model KNN 
model_knn = KNeighborsClassifier(n_neighbors=5)

#melatih model machine learning
model_knn.fit(x_train_smote,y_train_smote)

#menampilkan uji performa sisi training
y_pred_train_KNN = model_knn.predict(x_train_smote)

# menampilkan uji performa sisi testing
y_pred_test_KNN = model_knn.predict(x_test)

# %%
y_test
# Out:
# 713     0
# 436     0
# 770     1
# 1011    1
# 2325    1
#        ..
# 1751    0
# 2703    1
# 855     0
# 1284    1
# 2191    0
# Name: Outcome, Length: 554, dtype: int64

# %% [markdown]
# ## 5.2 Metriks Evaluasi Model KNN

# %%
# menampilkan akurasi sisi training
akurasi_traning_knn = accuracy_score(y_train_smote,y_pred_train_KNN)

# menampilkan akurasi sisi testing
akurasi_test_knn = accuracy_score(y_test,y_pred_test_KNN)

print("Hasil akurasi trainingnya adalah : ", akurasi_traning_knn*100)
print("Hasil akurasi testingnya adalah : ",akurasi_test_knn*100)
# Out:
# Hasil akurasi trainingnya adalah :  96.1459050240881
# Hasil akurasi testingnya adalah :  85.01805054151625

# %%
print("Classification report training:", classification_report(y_train_smote,y_pred_train_KNN))
# Out:
# Classification report training:               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96      1453
#            1       0.95      0.98      0.96      1453
#
#     accuracy                           0.96      2906
#    macro avg       0.96      0.96      0.96      2906
# weighted avg       0.96      0.96      0.96      2906

# %%
print("Classification report testing:", classification_report(y_test,y_pred_test_KNN))
# Out:
# Classification report testing:               precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88       363
#            1       0.73      0.90      0.80       191
#
#     accuracy                           0.85       554
#    macro avg       0.83      0.86      0.84       554
# weighted avg       0.87      0.85      0.85       554

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Confusion Matrix-training
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_train_smote, y_pred_train_KNN), annot=True, fmt='d', cmap='Blues', xticklabels=['No Diabetes', 'Diabetes'], yticklabels=['No Diabetes', 'Diabetes'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Confusion Matrix-training
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test,y_pred_test_KNN), annot=True, fmt='d', cmap='Blues', xticklabels=['No Diabetes', 'Diabetes'], yticklabels=['No Diabetes', 'Diabetes'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
#  ## 5.3. Matrik Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# ### Model Training Naive Bayes

# %%
# memuat model Gaussian NB
model_gnb = GaussianNB()

#melatih model machine learning
model_gnb.fit(x_train_smote,y_train_smote)

#menampilkan uji performa sisi training
y_pred_train_gnb = model_gnb.predict(x_train_smote)

# menampilkan uji performa sisi testing
y_pred_test_gnb = model_gnb.predict(x_test)

# %%
# menampilkan akurasi sisi training
akurasi_traning_gnb = accuracy_score(y_train_smote,y_pred_train_gnb)

# menampilkan akurasi sisi testing
akurasi_test_gnb = accuracy_score(y_test,y_pred_test_gnb)

print("Hasil akurasi trainingnya adalah : ", akurasi_traning_gnb*100)
print("Hasil akurasi testingnya adalah : ",akurasi_test_gnb*100)
# Out:
# Hasil akurasi trainingnya adalah :  73.81280110117
# Hasil akurasi testingnya adalah :  74.18772563176896

# %%
print("Classification report training:", classification_report(y_train_smote,y_pred_train_gnb))
print("Classification report testing:", classification_report(y_test,y_pred_test_gnb))
# Out:
# Classification report training:               precision    recall  f1-score   support
#
#            0       0.71      0.79      0.75      1453
#            1       0.77      0.68      0.72      1453
#
#     accuracy                           0.74      2906
#    macro avg       0.74      0.74      0.74      2906
# weighted avg       0.74      0.74      0.74      2906
#
# Classification report testing:               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79       363
#            1       0.61      0.70      0.65       191
#
#     accuracy                           0.74       554
#    macro avg       0.72      0.73      0.72       554
# weighted avg       0.75      0.74      0.75       554

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Confusion Matrix-training
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_train_smote, y_pred_train_gnb), annot=True, fmt='d', cmap='Blues', xticklabels=['No Diabetes', 'Diabetes'], yticklabels=['No Diabetes', 'Diabetes'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Confusion Matrix-testing
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test,y_pred_test_gnb), annot=True, fmt='d', cmap='Blues', xticklabels=['No Diabetes', 'Diabetes'], yticklabels=['No Diabetes', 'Diabetes'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## 5.4. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rfc = RandomForestClassifier(n_estimators=100, random_state=42)

model_rfc.fit(x_train_smote, y_train_smote)

#menghitung training 
y_pred_train_rfc = model_rfc.predict(x_train_smote)

y_pred_test_rfc = model_rfc.predict(x_test)

# %% [markdown]
# ### Metrik Evaluasi Random Forest

# %%
# menampilkan akurasi sisi training
akurasi_traning_rfc = accuracy_score(y_train_smote,y_pred_train_rfc)

# menampilkan akurasi sisi testing
akurasi_test_rfc = accuracy_score(y_test,y_pred_test_rfc)

print("Hasil akurasi trainingnya adalah : ", akurasi_traning_rfc*100)
print("Hasil akurasi testingnya adalah : ",akurasi_test_rfc*100)
# Out:
# Hasil akurasi trainingnya adalah :  100.0
# Hasil akurasi testingnya adalah :  99.63898916967509

# %%
print("Classification report training:", classification_report(y_train_smote,y_pred_train_rfc))
print("Classification report testing:", classification_report(y_test,y_pred_test_rfc))
# Out:
# Classification report training:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1453
#            1       1.00      1.00      1.00      1453
#
#     accuracy                           1.00      2906
#    macro avg       1.00      1.00      1.00      2906
# weighted avg       1.00      1.00      1.00      2906
#
# Classification report testing:               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       363
#            1       1.00      0.99      0.99       191
#
#     accuracy                           1.00       554
#    macro avg       1.00      0.99      1.00       554
# weighted avg       1.00      1.00      1.00       554

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(30, 15), dpi=300)  # Ukuran lebih besar dan resolusi tinggi
plot_tree(model_rfc.estimators_[0], feature_names=x.columns, class_names=["No Diabetes", "Diabetes"], filled=True)
plt.show()

# %%
import joblib
joblib.dump(model_rfc,"model_diabet_rfc.joblib")
# Out:
# ['model_diabet_rfc.joblib']

# %%
import pickle
with open ('model_rfc.pkl', 'wb') as f:
    pickle.dump(model_rfc, f)

# %% [markdown]
# # Memuat model

# %%
muat_model = joblib.load("model_diabet_rfc.joblib")

# %%
with open('model_rfc.pkl', 'rb') as f:
    model = pickle.load(f)

# %% [markdown]
# # 6. Memprediksi model baru (Program prediksi)

# %%
def prediksi_diabetes(model) : 
    print("=== Silakan masukkan data pasien ===")
    Pregnancies = int(input("Masukan Pregnancies : "))
    Glucose = int(input("Masukan Kadar Glukosa : "))
    BloodPressure = int(input("Masukan Tekanan Darah : "))
    SkinThickness = int(input("Masukan Ketebalan Kulit : "))
    Insulin = int(input("Masukan Kadar Insulin : "))
    BMI = float(input("Masukan BMI Pasien : "))
    DiabetesPedigreeFunction = float(input("Masukan DPF Pasien"))
    Age = int(input("Masukan umur Pasien : "))
    
    data_baru = np.array([Pregnancies,Glucose,BloodPressure,SkinThickness,Insulin,BMI,DiabetesPedigreeFunction,Age])
    data_baru = data_baru.reshape(1,-1)
    prediksi_baru = model.predict(data_baru)
    
    if prediksi_baru ==1:
        print("Pasien terkena Diabetes")
    else :
        print("Pasien tidak terkena Diabetes")

# %%
prediksi_diabetes(model_rfc)
# Out:
# === Silakan masukkan data pasien ===
